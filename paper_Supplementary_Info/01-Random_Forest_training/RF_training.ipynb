# %% [markdown]
# We show here how to train the Rhapsody random forest classifier in its final form.
#
# Based on the analyses illustrated in the `RF_optimization` notebook, we will make the following choices:
# * the training dataset will only contain SAVs with at least 1 review star in the ClinVar database (when available) and with same clinical interpretation in all 7 datasets
# * only PDB structures with at least 150 residues will be considered
# * the random forest classifier hyperparameters are set based on the optimization procedure (max. number of features = 2, number of trees in the forest = 1500)
# * dynamical features are computed from ANM without environmental effects (`chain` model)
#
# ## Importing training dataset

# %%
import sys, os
import pickle
import numpy as np
from glob import glob
from prody import LOGGER

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.family': 'Arial'})

# %%
# please make sure to extract the data folder beforehand
ID = np.load('../00-Training_Dataset/data/precomputed_features-ID.npy')
len(ID)
# Out:
# 91697

# %%
# let's discard SAVs with unknown significance (true_label == -1), ...
ID = ID[ID['true_label'] != -1]
len(ID)
# Out:
# 87726

# %%
# ... SAVs with associated PDB structure smaller than 150 residues ...
ID = ID[ ID['PDB_length' ] >= 150]
len(ID)
# Out:
# 23085

# %%
# ... and SAVs with 0 review star according to ClinVar
ID_SAVs_info = np.load('../00-Training_Dataset/data/Integrated_Dataset-SAVs.npy')
ClinVar_review_stars = {s['SAV_coords']: s['ClinVar_review_star'] for s in ID_SAVs_info}

ID = ID[ [ClinVar_review_stars[SAV] != 0 for SAV in ID['SAV_coords']] ]
len(ID)
# Out:
# 20361

# %%
# fraction of positives (dataset bias):
sum(ID['true_label']) / len(ID)
# Out:
# 0.6692205687343451

# %% [markdown]
# ## Training of Random Forest classifier
#
# We train 3 classifiers based on different set of features:

# %%
featsets = {
    'v2': [        # full classifier
        'wt_PSIC', 'Delta_PSIC', 'SASA', 
        'ANM_MSF-chain', 'ANM_effectiveness-chain', 'ANM_sensitivity-chain',
        'stiffness-chain', 'entropy', 'ranked_MI', 'BLOSUM'
    ],
    'v2_noPfam': [ # reduced classifier
        'wt_PSIC', 'Delta_PSIC', 'SASA', 
        'ANM_MSF-chain', 'ANM_effectiveness-chain', 'ANM_sensitivity-chain',
        'stiffness-chain', 'BLOSUM'
    ],
    'v2_EVmut': [  # full classifier + EVmutation epistatic score
        'wt_PSIC', 'Delta_PSIC', 'SASA', 
        'ANM_MSF-chain', 'ANM_effectiveness-chain', 'ANM_sensitivity-chain',
        'stiffness-chain', 'entropy', 'ranked_MI', 'BLOSUM', 'EVmut-DeltaE_epist'
    ],
}

# %%
# Insert here path to Rhapsody folder
sys.path.insert(0, '/home/lponzoni/Scratch/028-RHAPSODY-git/rhapsody')

from rhapsody import *

# %%
if not os.path.isdir('results'):
    os.mkdir('results')

# %%
if os.path.isfile('results/RF_training_summaries.pkl'):
    print('A pickle containing precomputed results have been found.')
    print('Please delete it if you wish to run the analysis again.')
else:
    LOGGER.start('results/RF_training.log')
    RF_training_summaries = {}

    for version in ['v2', 'v2_noPfam', 'v2_EVmut']:
        
        featset = ['SAV_coords', 'true_label'] + featsets[version]

        LOGGER.info(f'VERSION: {version}')

        # create folder
        folder = f'results/RF_training-{version}'
        os.mkdir(folder)

        # run training procedure
        output_dict = trainRFclassifier(ID[featset])
        RF_training_summaries[version] = output_dict['CV summary']

        # move trained classifier and figures into folder
        for file in glob('*png') + ['trained_classifier.pkl',]:
            os.rename(file, os.path.join(folder, file))

        LOGGER.info('')
                    
    # store all cross-validation results into a pickle
    pickle.dump(RF_training_summaries, open('results/RF_training_summaries.pkl', 'wb'))

    LOGGER.close('results/RF_training.log')
# Out:
# @> Logging into file: results/RF_training.log
# @> Logging started at 2019-05-24 18:01:57.226768
# @> VERSION: v2
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.864   AUPRC = 0.925   OOB score = 0.810
# @> CV iteration # 2:   AUROC = 0.864   AUPRC = 0.925   OOB score = 0.809
# @> CV iteration # 3:   AUROC = 0.844   AUPRC = 0.914   OOB score = 0.813
# @> CV iteration # 4:   AUROC = 0.870   AUPRC = 0.929   OOB score = 0.810
# @> CV iteration # 5:   AUROC = 0.856   AUPRC = 0.925   OOB score = 0.811
# @> CV iteration # 6:   AUROC = 0.850   AUPRC = 0.920   OOB score = 0.812
# @> CV iteration # 7:   AUROC = 0.860   AUPRC = 0.923   OOB score = 0.811
# @> CV iteration # 8:   AUROC = 0.859   AUPRC = 0.925   OOB score = 0.811
# @> CV iteration # 9:   AUROC = 0.845   AUPRC = 0.909   OOB score = 0.810
# @> CV iteration #10:   AUROC = 0.849   AUPRC = 0.915   OOB score = 0.811
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.856
# @> mean AUPRC:              0.921
# @> mean OOB score:          0.811
# @> optimal cutoff*:         0.697 +/- 0.037
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.152
# @>              Delta_PSIC: 0.203
# @>                    SASA: 0.075
# @>           ANM_MSF-chain: 0.083
# @> ANM_effectiveness-chain: 0.086
# @>   ANM_sensitivity-chain: 0.079
# @>         stiffness-chain: 0.090
# @>                 entropy: 0.108
# @>               ranked_MI: 0.076
# @>                  BLOSUM: 0.049
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.812
# @> feature importances:
# @>                 wt_PSIC: 0.154
# @>              Delta_PSIC: 0.200
# @>                    SASA: 0.075
# @>           ANM_MSF-chain: 0.083
# @> ANM_effectiveness-chain: 0.086
# @>   ANM_sensitivity-chain: 0.079
# @>         stiffness-chain: 0.090
# @>                 entropy: 0.107
# @>               ranked_MI: 0.076
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> VERSION: v2_noPfam
# @> 171 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.845   AUPRC = 0.900   OOB score = 0.796
# @> CV iteration # 2:   AUROC = 0.844   AUPRC = 0.906   OOB score = 0.796
# @> CV iteration # 3:   AUROC = 0.849   AUPRC = 0.909   OOB score = 0.796
# @> CV iteration # 4:   AUROC = 0.840   AUPRC = 0.899   OOB score = 0.796
# @> CV iteration # 5:   AUROC = 0.844   AUPRC = 0.904   OOB score = 0.797
# @> CV iteration # 6:   AUROC = 0.837   AUPRC = 0.900   OOB score = 0.795
# @> CV iteration # 7:   AUROC = 0.834   AUPRC = 0.896   OOB score = 0.797
# @> CV iteration # 8:   AUROC = 0.858   AUPRC = 0.920   OOB score = 0.794
# @> CV iteration # 9:   AUROC = 0.845   AUPRC = 0.906   OOB score = 0.797
# @> CV iteration #10:   AUROC = 0.840   AUPRC = 0.902   OOB score = 0.794
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20190
# @> fraction of positives:   0.669
# @> mean AUROC:              0.843
# @> mean AUPRC:              0.904
# @> mean OOB score:          0.796
# @> optimal cutoff*:         0.672 +/- 0.027
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.187
# @>              Delta_PSIC: 0.235
# @>                    SASA: 0.097
# @>           ANM_MSF-chain: 0.104
# @> ANM_effectiveness-chain: 0.107
# @>   ANM_sensitivity-chain: 0.102
# @>         stiffness-chain: 0.112
# @>                  BLOSUM: 0.056
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.797
# @> feature importances:
# @>                 wt_PSIC: 0.187
# @>              Delta_PSIC: 0.237
# @>                    SASA: 0.098
# @>           ANM_MSF-chain: 0.104
# @> ANM_effectiveness-chain: 0.107
# @>   ANM_sensitivity-chain: 0.102
# @>         stiffness-chain: 0.111
# @>                  BLOSUM: 0.055
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> VERSION: v2_EVmut
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.862   AUPRC = 0.937   OOB score = 0.831
# @> CV iteration # 2:   AUROC = 0.841   AUPRC = 0.923   OOB score = 0.831
# @> CV iteration # 3:   AUROC = 0.866   AUPRC = 0.942   OOB score = 0.833
# @> CV iteration # 4:   AUROC = 0.871   AUPRC = 0.944   OOB score = 0.831
# @> CV iteration # 5:   AUROC = 0.833   AUPRC = 0.931   OOB score = 0.835
# @> CV iteration # 6:   AUROC = 0.858   AUPRC = 0.939   OOB score = 0.832
# @> CV iteration # 7:   AUROC = 0.850   AUPRC = 0.933   OOB score = 0.832
# @> CV iteration # 8:   AUROC = 0.875   AUPRC = 0.948   OOB score = 0.831
# @> CV iteration # 9:   AUROC = 0.850   AUPRC = 0.935   OOB score = 0.833
# @> CV iteration #10:   AUROC = 0.842   AUPRC = 0.927   OOB score = 0.835
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.854
# @> mean AUPRC:              0.936
# @> mean OOB score:          0.832
# @> optimal cutoff*:         0.752 +/- 0.044
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.119
# @>              Delta_PSIC: 0.150
# @>                    SASA: 0.066
# @>           ANM_MSF-chain: 0.070
# @> ANM_effectiveness-chain: 0.077
# @>   ANM_sensitivity-chain: 0.072
# @>         stiffness-chain: 0.075
# @>                 entropy: 0.088
# @>               ranked_MI: 0.067
# @>                  BLOSUM: 0.039
# @>      EVmut-DeltaE_epist: 0.176
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.833
# @> feature importances:
# @>                 wt_PSIC: 0.116
# @>              Delta_PSIC: 0.150
# @>                    SASA: 0.066
# @>           ANM_MSF-chain: 0.070
# @> ANM_effectiveness-chain: 0.078
# @>   ANM_sensitivity-chain: 0.072
# @>         stiffness-chain: 0.075
# @>                 entropy: 0.086
# @>               ranked_MI: 0.067
# @>                  BLOSUM: 0.038
# @>      EVmut-DeltaE_epist: 0.181
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> Logging stopped at 2019-05-24 18:09:07.687791
# @> Closing logfile: results/RF_training.log

# %%
# recover precomputed training results
RF_training_summaries = pickle.load(open('results/RF_training_summaries.pkl', 'rb'))

# %% [markdown]
# ## Comparison with PolyPhen-2 and EVmutation
#
# Let's recover a NumPy array containing predictions from PolyPhen-2:

# %%
pph2_predictions = np.load('../00-Training_Dataset/data/PolyPhen2_predictions-ID.npy')
pph2_predictions.dtype
# Out:
# dtype([('SAV_coords', '<U25'), ('prediction', '<U25'), ('pph2_class', '<U25'), ('pph2_prob', '<f4')])

# %%
# We select the same subset of the Integrated Dataset as the one used for Rhapsody
pph2_predictions = pph2_predictions[ [SAV in ID['SAV_coords'] for SAV in pph2_predictions['SAV_coords']] ]

# %%
# NB: the two arrays should be sorted in the same way
assert all(pph2_predictions['SAV_coords'] == ID['SAV_coords'])

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve, average_precision_score

PP2_EVm_metrics = {}

pred_scores = {
    'PolyPhen-2' : pph2_predictions['pph2_prob'],
    'EVmutation': - ID['EVmut-DeltaE_epist']
}

for method, score in pred_scores.items():
    # let's discard NaN values
    sel = ~np.isnan(score)
    predictions = score[sel]
    true_labels = ID['true_label'][sel]
    
    # Rhapsody contains a function for computing ROC, Precision-Recall curves, etc.
    m = calcMetrics(true_labels, predictions)
    m['dataset size'] = sum(sel)
    PP2_EVm_metrics[method] = m
    
    print(f'{method:11}:', f"  n.SAVs = {m['dataset size']}", 
          f"   AUROC = {m['AUROC']:.3f}",
          f"   AUPRC = {m['AUPRC']:.3f}")
# Out:
# PolyPhen-2 :   n.SAVs = 20360    AUROC = 0.799    AUPRC = 0.857
# EVmutation :   n.SAVs = 13644    AUROC = 0.808    AUPRC = 0.908

# %%
# print summary from Rhapsody training
for v, s in RF_training_summaries.items():
    print(f'{v:11}:', f"  n.SAVs = {s['dataset size']}", 
          f"   AUROC = {s['mean AUROC']:.3f}",
          f"   AUPRC = {s['mean AUPRC']:.3f}",
          f"   OOB score = {s['mean OOB score']:.3f}")
# Out:
# v2         :   n.SAVs = 16443    AUROC = 0.856    AUPRC = 0.921    OOB score = 0.811
# v2_noPfam  :   n.SAVs = 20190    AUROC = 0.843    AUPRC = 0.904    OOB score = 0.796
# v2_EVmut   :   n.SAVs = 13033    AUROC = 0.854    AUPRC = 0.936    OOB score = 0.832

# %%
if not os.path.isdir('figures'):
    os.mkdir('figures')

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

data = np.zeros((5,4))
for i, v in enumerate(['v2', 'v2_noPfam', 'v2_EVmut']):
    for j, x in enumerate(['mean AUROC', 'mean AUPRC', 'mean OOB score', 'dataset size']):
        data[i,j] = RF_training_summaries[v][x]
for i, v in enumerate(['PolyPhen-2', 'EVmutation']):
    for j, x in enumerate(['AUROC', 'AUPRC', 'dataset size']):
        if x=='dataset size': j+=1
        data[i+3,j] = PP2_EVm_metrics[v][x]

# bar plots
X = np.array([0, 1, 2, 3.1, 4.1])

h0 = ax.bar(X + 0.2, data[:,1], color = 'C1', width=.4, edgecolor='w', label='AUPRC')
h1 = ax.bar(X + 0.3, data[:,2], color = 'C7', width=.4, edgecolor='w', label='OOB score')
h2 = ax.bar(X + 0.0, data[:,0], color = 'C0', width=.4, edgecolor='w', label='AUROC')

ax2 = ax.twinx()
hb = ax2.bar(X + 0.4, data[:,3], color = 'C8', width=.4, alpha=0.4, label='dataset\nsize')
ax2.set_zorder(ax.get_zorder()-1)
ax.patch.set_visible(False)

handles = [h2, h0, h1]
ax.legend(handles, [h.get_label() for h in handles], handlelength=1, fontsize=9, 
          loc='upper left', labelspacing=.3)
ax2.legend(handlelength=1, fontsize=9, loc='upper right', labelspacing=.3)

ax.set_ylim((0.71,1))
ax.set_xlim((-.4, 4.9))

ax.set_xticks([])
for i,s in enumerate(['Rhapsody (full)', 'Rhapsody (redux)', 'Rhapsody+EVmut', 'PolyPhen-2', 'EVmutation']):
    ax.text(X[i]-.065, 0.718, s, color='w', rotation=90, va='bottom', size='11')

ax2.set_ylim((0, 21000))
ax2.set_yticks(range(4000, 21000, 4000))
ax2.set_yticklabels(['4k\nSAVs', '8k\nSAVs', '12k\nSAVs', '16k\nSAVs', '20k\nSAVs'])

ax.axvline(x=2.76, color='gray', ls='--', alpha=.5)

fig.savefig('figures/Rhapsody_vs_PP2_EVmut.png', dpi=300)

# %% [markdown]
# ## Feature importances
#
# We can assess the relative importance of each feature by looking at their weights in the random forest.

# %%
abbrv = {
    'ANM_MSF-chain': 'ANM-MSF',
    'ANM_effectiveness-chain': 'ANM-effectivness',
    'ANM_sensitivity-chain': 'ANM-sensitivity',
    'BLOSUM': 'BLOSUM',
    'Delta_PSIC': 'ΔPSIC', 
    'EVmut-DeltaE_epist': 'ΔE EVmutation',
    'SASA': 'SASA',
    'entropy': 'entropy',
    'ranked_MI': 'MI',
    'stiffness-chain': 'ANM-stiffness',
    'wt_PSIC': 'wtPSIC',
    'v2': 'Rhapsody (full)',
    'v2_noPfam': 'Rhapsody (redux)',
    'v2_EVmut': 'Rhapsody+EVmutation',
}

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

for i, (version, d) in enumerate(RF_training_summaries.items()):
    
    featset = featsets[version]
    n = len(featset)
    
    data = d['feat. importance']

    ax = axes[i]
    ax.set_title(abbrv[version])
    
    # bar plots
    X = np.arange(n)
    ax.bar(X, d['feat. importance'], color='C4', width=.8, edgecolor='w')

    ax.set_xlim((-.7, n-0.3))
    
    ax.set_xticks([])
    labels = [abbrv[f] for f in featsets[version]]
    ax.set_xticklabels(labels, rotation='vertical')
    
    for i,s in enumerate([abbrv[f] for f in featset]):
        ax.text(X[i]+.1, 0.003, s, color='w', rotation=90, ha='center', va='bottom', size='10')

fig.savefig('figures/feature_importances.png', dpi=300)

# %% [markdown]
# ## Leave-one-feature-out analysis
#
# An alternative approach to measure a feature's importance is to cross-validate the classifier by leaving out one feature at a time and measure the effect on accuracy.

# %%
if os.path.isfile('results/LOFO_summaries.pkl'):
    print('A pickle containing precomputed results have been found.')
    print('Please delete it if you wish to run the analysis again.')
else:
    LOGGER.start('results/LOFO_analysis.log')
    LOFO_summaries = {}

    for version in ['v2', 'v2_noPfam', 'v2_EVmut']:
        
        LOFO_summaries[version] = {}
        
        featset = featsets[version]

        for f_left_out in featset:

            _featset = ['SAV_coords', 'true_label'] + [f for f in featset if f != f_left_out]

            LOGGER.info(f'VERSION: {version} - FEATURE LEFT OUT: {f_left_out}')

            # create folder
            folder = f'results/LOFO-{version}-{f_left_out}'
            os.mkdir(folder)

            # run cross-validation
            LOFO_summaries[version][f_left_out] = RandomForestCV(ID[_featset])

            # move figures into folder
            for file in glob('*png'):
                os.rename(file, os.path.join(folder, file))

            LOGGER.info('')
                    
    # store all cross-validation results into a pickle
    pickle.dump(LOFO_summaries, open('results/LOFO_summaries.pkl', 'wb'))

    LOGGER.close('results/LOFO_analysis.log')
# Out:
# @> Logging into file: results/LOFO_analysis.log
# @> Logging started at 2019-05-27 10:18:49.373060
# @> VERSION: v2 - FEATURE LEFT OUT: wt_PSIC
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.857   AUPRC = 0.917   OOB score = 0.807
# @> CV iteration # 2:   AUROC = 0.861   AUPRC = 0.921   OOB score = 0.808
# @> CV iteration # 3:   AUROC = 0.838   AUPRC = 0.909   OOB score = 0.809
# @> CV iteration # 4:   AUROC = 0.866   AUPRC = 0.927   OOB score = 0.806
# @> CV iteration # 5:   AUROC = 0.858   AUPRC = 0.925   OOB score = 0.808
# @> CV iteration # 6:   AUROC = 0.843   AUPRC = 0.916   OOB score = 0.809
# @> CV iteration # 7:   AUROC = 0.858   AUPRC = 0.924   OOB score = 0.807
# @> CV iteration # 8:   AUROC = 0.854   AUPRC = 0.922   OOB score = 0.809
# @> CV iteration # 9:   AUROC = 0.839   AUPRC = 0.905   OOB score = 0.809
# @> CV iteration #10:   AUROC = 0.839   AUPRC = 0.910   OOB score = 0.810
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.851
# @> mean AUPRC:              0.918
# @> mean OOB score:          0.808
# @> optimal cutoff*:         0.694 +/- 0.041
# @> (* argmax of Youden's index)
# @> feature importances:
# @>              Delta_PSIC: 0.249
# @>                    SASA: 0.088
# @>           ANM_MSF-chain: 0.095
# @> ANM_effectiveness-chain: 0.098
# @>   ANM_sensitivity-chain: 0.090
# @>         stiffness-chain: 0.104
# @>                 entropy: 0.133
# @>               ranked_MI: 0.089
# @>                  BLOSUM: 0.054
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: Delta_PSIC
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.864   AUPRC = 0.926   OOB score = 0.802
# @> CV iteration # 2:   AUROC = 0.864   AUPRC = 0.930   OOB score = 0.804
# @> CV iteration # 3:   AUROC = 0.841   AUPRC = 0.915   OOB score = 0.802
# @> CV iteration # 4:   AUROC = 0.861   AUPRC = 0.928   OOB score = 0.801
# @> CV iteration # 5:   AUROC = 0.847   AUPRC = 0.923   OOB score = 0.804
# @> CV iteration # 6:   AUROC = 0.851   AUPRC = 0.924   OOB score = 0.806
# @> CV iteration # 7:   AUROC = 0.852   AUPRC = 0.922   OOB score = 0.803
# @> CV iteration # 8:   AUROC = 0.853   AUPRC = 0.926   OOB score = 0.805
# @> CV iteration # 9:   AUROC = 0.842   AUPRC = 0.914   OOB score = 0.804
# @> CV iteration #10:   AUROC = 0.853   AUPRC = 0.916   OOB score = 0.804
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.852
# @> mean AUPRC:              0.922
# @> mean OOB score:          0.803
# @> optimal cutoff*:         0.709 +/- 0.020
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.213
# @>                    SASA: 0.088
# @>           ANM_MSF-chain: 0.098
# @> ANM_effectiveness-chain: 0.101
# @>   ANM_sensitivity-chain: 0.093
# @>         stiffness-chain: 0.109
# @>                 entropy: 0.132
# @>               ranked_MI: 0.092
# @>                  BLOSUM: 0.074
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: SASA
# @> 3769 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.860   AUPRC = 0.924   OOB score = 0.811
# @> CV iteration # 2:   AUROC = 0.856   AUPRC = 0.917   OOB score = 0.809
# @> CV iteration # 3:   AUROC = 0.864   AUPRC = 0.925   OOB score = 0.809
# @> CV iteration # 4:   AUROC = 0.846   AUPRC = 0.917   OOB score = 0.811
# @> CV iteration # 5:   AUROC = 0.861   AUPRC = 0.926   OOB score = 0.810
# @> CV iteration # 6:   AUROC = 0.858   AUPRC = 0.922   OOB score = 0.810
# @> CV iteration # 7:   AUROC = 0.853   AUPRC = 0.923   OOB score = 0.810
# @> CV iteration # 8:   AUROC = 0.848   AUPRC = 0.915   OOB score = 0.810
# @> CV iteration # 9:   AUROC = 0.831   AUPRC = 0.901   OOB score = 0.812
# @> CV iteration #10:   AUROC = 0.859   AUPRC = 0.924   OOB score = 0.811
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16592
# @> fraction of positives:   0.690
# @> mean AUROC:              0.853
# @> mean AUPRC:              0.919
# @> mean OOB score:          0.810
# @> optimal cutoff*:         0.702 +/- 0.033
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.164
# @>              Delta_PSIC: 0.213
# @>           ANM_MSF-chain: 0.091
# @> ANM_effectiveness-chain: 0.094
# @>   ANM_sensitivity-chain: 0.086
# @>         stiffness-chain: 0.100
# @>                 entropy: 0.117
# @>               ranked_MI: 0.084
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: ANM_MSF-chain
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.861   AUPRC = 0.922   OOB score = 0.808
# @> CV iteration # 2:   AUROC = 0.858   AUPRC = 0.919   OOB score = 0.809
# @> CV iteration # 3:   AUROC = 0.841   AUPRC = 0.911   OOB score = 0.812
# @> CV iteration # 4:   AUROC = 0.869   AUPRC = 0.929   OOB score = 0.809
# @> CV iteration # 5:   AUROC = 0.853   AUPRC = 0.921   OOB score = 0.810
# @> CV iteration # 6:   AUROC = 0.846   AUPRC = 0.918   OOB score = 0.811
# @> CV iteration # 7:   AUROC = 0.854   AUPRC = 0.920   OOB score = 0.810
# @> CV iteration # 8:   AUROC = 0.853   AUPRC = 0.920   OOB score = 0.810
# @> CV iteration # 9:   AUROC = 0.842   AUPRC = 0.905   OOB score = 0.809
# @> CV iteration #10:   AUROC = 0.850   AUPRC = 0.914   OOB score = 0.810
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.853
# @> mean AUPRC:              0.918
# @> mean OOB score:          0.810
# @> optimal cutoff*:         0.694 +/- 0.034
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.163
# @>              Delta_PSIC: 0.215
# @>                    SASA: 0.083
# @> ANM_effectiveness-chain: 0.095
# @>   ANM_sensitivity-chain: 0.090
# @>         stiffness-chain: 0.101
# @>                 entropy: 0.117
# @>               ranked_MI: 0.085
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: ANM_effectiveness-chain
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.859   AUPRC = 0.922   OOB score = 0.807
# @> CV iteration # 2:   AUROC = 0.856   AUPRC = 0.920   OOB score = 0.810
# @> CV iteration # 3:   AUROC = 0.837   AUPRC = 0.910   OOB score = 0.808
# @> CV iteration # 4:   AUROC = 0.862   AUPRC = 0.923   OOB score = 0.810
# @> CV iteration # 5:   AUROC = 0.853   AUPRC = 0.921   OOB score = 0.810
# @> CV iteration # 6:   AUROC = 0.845   AUPRC = 0.916   OOB score = 0.809
# @> CV iteration # 7:   AUROC = 0.856   AUPRC = 0.921   OOB score = 0.808
# @> CV iteration # 8:   AUROC = 0.859   AUPRC = 0.925   OOB score = 0.809
# @> CV iteration # 9:   AUROC = 0.839   AUPRC = 0.905   OOB score = 0.809
# @> CV iteration #10:   AUROC = 0.846   AUPRC = 0.912   OOB score = 0.809
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.851
# @> mean AUPRC:              0.918
# @> mean OOB score:          0.809
# @> optimal cutoff*:         0.695 +/- 0.023
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.162
# @>              Delta_PSIC: 0.216
# @>                    SASA: 0.083
# @>           ANM_MSF-chain: 0.092
# @>   ANM_sensitivity-chain: 0.093
# @>         stiffness-chain: 0.098
# @>                 entropy: 0.118
# @>               ranked_MI: 0.086
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: ANM_sensitivity-chain
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.862   AUPRC = 0.924   OOB score = 0.809
# @> CV iteration # 2:   AUROC = 0.862   AUPRC = 0.922   OOB score = 0.811
# @> CV iteration # 3:   AUROC = 0.838   AUPRC = 0.909   OOB score = 0.812
# @> CV iteration # 4:   AUROC = 0.867   AUPRC = 0.928   OOB score = 0.810
# @> CV iteration # 5:   AUROC = 0.855   AUPRC = 0.924   OOB score = 0.813
# @> CV iteration # 6:   AUROC = 0.846   AUPRC = 0.917   OOB score = 0.812
# @> CV iteration # 7:   AUROC = 0.859   AUPRC = 0.922   OOB score = 0.811
# @> CV iteration # 8:   AUROC = 0.856   AUPRC = 0.923   OOB score = 0.809
# @> CV iteration # 9:   AUROC = 0.844   AUPRC = 0.908   OOB score = 0.810
# @> CV iteration #10:   AUROC = 0.847   AUPRC = 0.912   OOB score = 0.810
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.853
# @> mean AUPRC:              0.919
# @> mean OOB score:          0.811
# @> optimal cutoff*:         0.706 +/- 0.029
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.163
# @>              Delta_PSIC: 0.214
# @>                    SASA: 0.082
# @>           ANM_MSF-chain: 0.093
# @> ANM_effectiveness-chain: 0.098
# @>         stiffness-chain: 0.099
# @>                 entropy: 0.116
# @>               ranked_MI: 0.084
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: stiffness-chain
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.859   AUPRC = 0.919   OOB score = 0.806
# @> CV iteration # 2:   AUROC = 0.860   AUPRC = 0.919   OOB score = 0.806
# @> CV iteration # 3:   AUROC = 0.840   AUPRC = 0.910   OOB score = 0.809
# @> CV iteration # 4:   AUROC = 0.864   AUPRC = 0.925   OOB score = 0.808
# @> CV iteration # 5:   AUROC = 0.852   AUPRC = 0.922   OOB score = 0.808
# @> CV iteration # 6:   AUROC = 0.842   AUPRC = 0.915   OOB score = 0.809
# @> CV iteration # 7:   AUROC = 0.854   AUPRC = 0.921   OOB score = 0.809
# @> CV iteration # 8:   AUROC = 0.851   AUPRC = 0.919   OOB score = 0.807
# @> CV iteration # 9:   AUROC = 0.839   AUPRC = 0.904   OOB score = 0.807
# @> CV iteration #10:   AUROC = 0.842   AUPRC = 0.909   OOB score = 0.808
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.850
# @> mean AUPRC:              0.916
# @> mean OOB score:          0.808
# @> optimal cutoff*:         0.699 +/- 0.030
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.163
# @>              Delta_PSIC: 0.217
# @>                    SASA: 0.085
# @>           ANM_MSF-chain: 0.096
# @> ANM_effectiveness-chain: 0.094
# @>   ANM_sensitivity-chain: 0.088
# @>                 entropy: 0.119
# @>               ranked_MI: 0.086
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: entropy
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.856   AUPRC = 0.919   OOB score = 0.807
# @> CV iteration # 2:   AUROC = 0.858   AUPRC = 0.921   OOB score = 0.808
# @> CV iteration # 3:   AUROC = 0.837   AUPRC = 0.908   OOB score = 0.810
# @> CV iteration # 4:   AUROC = 0.865   AUPRC = 0.926   OOB score = 0.809
# @> CV iteration # 5:   AUROC = 0.853   AUPRC = 0.921   OOB score = 0.807
# @> CV iteration # 6:   AUROC = 0.850   AUPRC = 0.920   OOB score = 0.808
# @> CV iteration # 7:   AUROC = 0.854   AUPRC = 0.920   OOB score = 0.808
# @> CV iteration # 8:   AUROC = 0.854   AUPRC = 0.922   OOB score = 0.807
# @> CV iteration # 9:   AUROC = 0.843   AUPRC = 0.906   OOB score = 0.806
# @> CV iteration #10:   AUROC = 0.842   AUPRC = 0.908   OOB score = 0.808
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.851
# @> mean AUPRC:              0.917
# @> mean OOB score:          0.808
# @> optimal cutoff*:         0.685 +/- 0.045
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.173
# @>              Delta_PSIC: 0.221
# @>                    SASA: 0.086
# @>           ANM_MSF-chain: 0.093
# @> ANM_effectiveness-chain: 0.097
# @>   ANM_sensitivity-chain: 0.090
# @>         stiffness-chain: 0.102
# @>               ranked_MI: 0.086
# @>                  BLOSUM: 0.052
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: ranked_MI
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.863   AUPRC = 0.924   OOB score = 0.808
# @> CV iteration # 2:   AUROC = 0.862   AUPRC = 0.923   OOB score = 0.808
# @> CV iteration # 3:   AUROC = 0.840   AUPRC = 0.909   OOB score = 0.811
# @> CV iteration # 4:   AUROC = 0.868   AUPRC = 0.926   OOB score = 0.808
# @> CV iteration # 5:   AUROC = 0.854   AUPRC = 0.921   OOB score = 0.809
# @> CV iteration # 6:   AUROC = 0.848   AUPRC = 0.916   OOB score = 0.810
# @> CV iteration # 7:   AUROC = 0.858   AUPRC = 0.922   OOB score = 0.809
# @> CV iteration # 8:   AUROC = 0.855   AUPRC = 0.922   OOB score = 0.809
# @> CV iteration # 9:   AUROC = 0.846   AUPRC = 0.908   OOB score = 0.808
# @> CV iteration #10:   AUROC = 0.848   AUPRC = 0.915   OOB score = 0.811
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.854
# @> mean AUPRC:              0.919
# @> mean OOB score:          0.809
# @> optimal cutoff*:         0.702 +/- 0.034
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.162
# @>              Delta_PSIC: 0.215
# @>                    SASA: 0.082
# @>           ANM_MSF-chain: 0.091
# @> ANM_effectiveness-chain: 0.095
# @>   ANM_sensitivity-chain: 0.088
# @>         stiffness-chain: 0.099
# @>                 entropy: 0.117
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2 - FEATURE LEFT OUT: BLOSUM
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.863   AUPRC = 0.927   OOB score = 0.808
# @> CV iteration # 2:   AUROC = 0.863   AUPRC = 0.925   OOB score = 0.810
# @> CV iteration # 3:   AUROC = 0.847   AUPRC = 0.918   OOB score = 0.813
# @> CV iteration # 4:   AUROC = 0.873   AUPRC = 0.931   OOB score = 0.808
# @> CV iteration # 5:   AUROC = 0.855   AUPRC = 0.924   OOB score = 0.809
# @> CV iteration # 6:   AUROC = 0.847   AUPRC = 0.918   OOB score = 0.813
# @> CV iteration # 7:   AUROC = 0.862   AUPRC = 0.925   OOB score = 0.809
# @> CV iteration # 8:   AUROC = 0.856   AUPRC = 0.923   OOB score = 0.812
# @> CV iteration # 9:   AUROC = 0.843   AUPRC = 0.908   OOB score = 0.810
# @> CV iteration #10:   AUROC = 0.848   AUPRC = 0.915   OOB score = 0.810
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.855
# @> mean AUPRC:              0.921
# @> mean OOB score:          0.810
# @> optimal cutoff*:         0.713 +/- 0.031
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.156
# @>              Delta_PSIC: 0.222
# @>                    SASA: 0.077
# @>           ANM_MSF-chain: 0.086
# @> ANM_effectiveness-chain: 0.090
# @>   ANM_sensitivity-chain: 0.083
# @>         stiffness-chain: 0.094
# @>                 entropy: 0.112
# @>               ranked_MI: 0.080
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: wt_PSIC
# @> 171 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.833   AUPRC = 0.893   OOB score = 0.789
# @> CV iteration # 2:   AUROC = 0.828   AUPRC = 0.897   OOB score = 0.791
# @> CV iteration # 3:   AUROC = 0.833   AUPRC = 0.895   OOB score = 0.788
# @> CV iteration # 4:   AUROC = 0.828   AUPRC = 0.895   OOB score = 0.789
# @> CV iteration # 5:   AUROC = 0.825   AUPRC = 0.892   OOB score = 0.788
# @> CV iteration # 6:   AUROC = 0.824   AUPRC = 0.890   OOB score = 0.787
# @> CV iteration # 7:   AUROC = 0.823   AUPRC = 0.885   OOB score = 0.789
# @> CV iteration # 8:   AUROC = 0.850   AUPRC = 0.914   OOB score = 0.785
# @> CV iteration # 9:   AUROC = 0.830   AUPRC = 0.898   OOB score = 0.788
# @> CV iteration #10:   AUROC = 0.832   AUPRC = 0.899   OOB score = 0.788
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20190
# @> fraction of positives:   0.669
# @> mean AUROC:              0.830
# @> mean AUPRC:              0.896
# @> mean OOB score:          0.788
# @> optimal cutoff*:         0.670 +/- 0.051
# @> (* argmax of Youden's index)
# @> feature importances:
# @>              Delta_PSIC: 0.304
# @>                    SASA: 0.119
# @>           ANM_MSF-chain: 0.126
# @> ANM_effectiveness-chain: 0.130
# @>   ANM_sensitivity-chain: 0.122
# @>         stiffness-chain: 0.135
# @>                  BLOSUM: 0.063
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: Delta_PSIC
# @> 170 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.840   AUPRC = 0.907   OOB score = 0.790
# @> CV iteration # 2:   AUROC = 0.846   AUPRC = 0.907   OOB score = 0.789
# @> CV iteration # 3:   AUROC = 0.846   AUPRC = 0.912   OOB score = 0.788
# @> CV iteration # 4:   AUROC = 0.835   AUPRC = 0.900   OOB score = 0.790
# @> CV iteration # 5:   AUROC = 0.834   AUPRC = 0.903   OOB score = 0.792
# @> CV iteration # 6:   AUROC = 0.831   AUPRC = 0.906   OOB score = 0.791
# @> CV iteration # 7:   AUROC = 0.822   AUPRC = 0.893   OOB score = 0.793
# @> CV iteration # 8:   AUROC = 0.845   AUPRC = 0.912   OOB score = 0.789
# @> CV iteration # 9:   AUROC = 0.840   AUPRC = 0.904   OOB score = 0.790
# @> CV iteration #10:   AUROC = 0.845   AUPRC = 0.908   OOB score = 0.787
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20191
# @> fraction of positives:   0.669
# @> mean AUROC:              0.838
# @> mean AUPRC:              0.905
# @> mean OOB score:          0.790
# @> optimal cutoff*:         0.681 +/- 0.030
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.273
# @>                    SASA: 0.118
# @>           ANM_MSF-chain: 0.128
# @> ANM_effectiveness-chain: 0.132
# @>   ANM_sensitivity-chain: 0.125
# @>         stiffness-chain: 0.140
# @>                  BLOSUM: 0.083
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: SASA
# @> 1 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.839   AUPRC = 0.902   OOB score = 0.793
# @> CV iteration # 2:   AUROC = 0.834   AUPRC = 0.895   OOB score = 0.793
# @> CV iteration # 3:   AUROC = 0.833   AUPRC = 0.898   OOB score = 0.793
# @> CV iteration # 4:   AUROC = 0.860   AUPRC = 0.914   OOB score = 0.791
# @> CV iteration # 5:   AUROC = 0.847   AUPRC = 0.909   OOB score = 0.792
# @> CV iteration # 6:   AUROC = 0.839   AUPRC = 0.903   OOB score = 0.794
# @> CV iteration # 7:   AUROC = 0.832   AUPRC = 0.890   OOB score = 0.795
# @> CV iteration # 8:   AUROC = 0.827   AUPRC = 0.895   OOB score = 0.794
# @> CV iteration # 9:   AUROC = 0.845   AUPRC = 0.905   OOB score = 0.793
# @> CV iteration #10:   AUROC = 0.837   AUPRC = 0.894   OOB score = 0.795
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20360
# @> fraction of positives:   0.669
# @> mean AUROC:              0.839
# @> mean AUPRC:              0.900
# @> mean OOB score:          0.793
# @> optimal cutoff*:         0.682 +/- 0.031
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.205
# @>              Delta_PSIC: 0.253
# @>           ANM_MSF-chain: 0.119
# @> ANM_effectiveness-chain: 0.122
# @>   ANM_sensitivity-chain: 0.114
# @>         stiffness-chain: 0.129
# @>                  BLOSUM: 0.058
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: ANM_MSF-chain
# @> 171 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.842   AUPRC = 0.898   OOB score = 0.794
# @> CV iteration # 2:   AUROC = 0.836   AUPRC = 0.900   OOB score = 0.794
# @> CV iteration # 3:   AUROC = 0.845   AUPRC = 0.906   OOB score = 0.793
# @> CV iteration # 4:   AUROC = 0.833   AUPRC = 0.891   OOB score = 0.795
# @> CV iteration # 5:   AUROC = 0.841   AUPRC = 0.901   OOB score = 0.795
# @> CV iteration # 6:   AUROC = 0.833   AUPRC = 0.896   OOB score = 0.794
# @> CV iteration # 7:   AUROC = 0.830   AUPRC = 0.892   OOB score = 0.794
# @> CV iteration # 8:   AUROC = 0.853   AUPRC = 0.914   OOB score = 0.793
# @> CV iteration # 9:   AUROC = 0.843   AUPRC = 0.907   OOB score = 0.795
# @> CV iteration #10:   AUROC = 0.836   AUPRC = 0.901   OOB score = 0.793
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20190
# @> fraction of positives:   0.669
# @> mean AUROC:              0.839
# @> mean AUPRC:              0.901
# @> mean OOB score:          0.794
# @> optimal cutoff*:         0.676 +/- 0.029
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.203
# @>              Delta_PSIC: 0.256
# @>                    SASA: 0.110
# @> ANM_effectiveness-chain: 0.124
# @>   ANM_sensitivity-chain: 0.120
# @>         stiffness-chain: 0.130
# @>                  BLOSUM: 0.058
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: ANM_effectiveness-chain
# @> 171 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.837   AUPRC = 0.893   OOB score = 0.795
# @> CV iteration # 2:   AUROC = 0.834   AUPRC = 0.896   OOB score = 0.793
# @> CV iteration # 3:   AUROC = 0.841   AUPRC = 0.904   OOB score = 0.793
# @> CV iteration # 4:   AUROC = 0.834   AUPRC = 0.890   OOB score = 0.794
# @> CV iteration # 5:   AUROC = 0.836   AUPRC = 0.899   OOB score = 0.794
# @> CV iteration # 6:   AUROC = 0.828   AUPRC = 0.890   OOB score = 0.793
# @> CV iteration # 7:   AUROC = 0.827   AUPRC = 0.889   OOB score = 0.794
# @> CV iteration # 8:   AUROC = 0.849   AUPRC = 0.912   OOB score = 0.793
# @> CV iteration # 9:   AUROC = 0.842   AUPRC = 0.903   OOB score = 0.794
# @> CV iteration #10:   AUROC = 0.831   AUPRC = 0.893   OOB score = 0.793
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20190
# @> fraction of positives:   0.669
# @> mean AUROC:              0.836
# @> mean AUPRC:              0.897
# @> mean OOB score:          0.794
# @> optimal cutoff*:         0.673 +/- 0.032
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.205
# @>              Delta_PSIC: 0.257
# @>                    SASA: 0.110
# @>           ANM_MSF-chain: 0.120
# @>   ANM_sensitivity-chain: 0.123
# @>         stiffness-chain: 0.127
# @>                  BLOSUM: 0.059
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: ANM_sensitivity-chain
# @> 171 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.841   AUPRC = 0.897   OOB score = 0.795
# @> CV iteration # 2:   AUROC = 0.839   AUPRC = 0.903   OOB score = 0.795
# @> CV iteration # 3:   AUROC = 0.845   AUPRC = 0.905   OOB score = 0.794
# @> CV iteration # 4:   AUROC = 0.835   AUPRC = 0.892   OOB score = 0.794
# @> CV iteration # 5:   AUROC = 0.837   AUPRC = 0.901   OOB score = 0.794
# @> CV iteration # 6:   AUROC = 0.831   AUPRC = 0.894   OOB score = 0.796
# @> CV iteration # 7:   AUROC = 0.830   AUPRC = 0.891   OOB score = 0.794
# @> CV iteration # 8:   AUROC = 0.853   AUPRC = 0.915   OOB score = 0.794
# @> CV iteration # 9:   AUROC = 0.839   AUPRC = 0.902   OOB score = 0.794
# @> CV iteration #10:   AUROC = 0.836   AUPRC = 0.898   OOB score = 0.794
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20190
# @> fraction of positives:   0.669
# @> mean AUROC:              0.838
# @> mean AUPRC:              0.900
# @> mean OOB score:          0.794
# @> optimal cutoff*:         0.673 +/- 0.032
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.203
# @>              Delta_PSIC: 0.255
# @>                    SASA: 0.109
# @>           ANM_MSF-chain: 0.121
# @> ANM_effectiveness-chain: 0.127
# @>         stiffness-chain: 0.127
# @>                  BLOSUM: 0.059
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: stiffness-chain
# @> 171 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.840   AUPRC = 0.894   OOB score = 0.794
# @> CV iteration # 2:   AUROC = 0.834   AUPRC = 0.898   OOB score = 0.793
# @> CV iteration # 3:   AUROC = 0.841   AUPRC = 0.902   OOB score = 0.793
# @> CV iteration # 4:   AUROC = 0.834   AUPRC = 0.894   OOB score = 0.793
# @> CV iteration # 5:   AUROC = 0.837   AUPRC = 0.894   OOB score = 0.794
# @> CV iteration # 6:   AUROC = 0.830   AUPRC = 0.892   OOB score = 0.795
# @> CV iteration # 7:   AUROC = 0.824   AUPRC = 0.885   OOB score = 0.795
# @> CV iteration # 8:   AUROC = 0.849   AUPRC = 0.913   OOB score = 0.793
# @> CV iteration # 9:   AUROC = 0.834   AUPRC = 0.897   OOB score = 0.795
# @> CV iteration #10:   AUROC = 0.834   AUPRC = 0.897   OOB score = 0.793
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20190
# @> fraction of positives:   0.669
# @> mean AUROC:              0.835
# @> mean AUPRC:              0.896
# @> mean OOB score:          0.794
# @> optimal cutoff*:         0.682 +/- 0.024
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.205
# @>              Delta_PSIC: 0.258
# @>                    SASA: 0.112
# @>           ANM_MSF-chain: 0.126
# @> ANM_effectiveness-chain: 0.123
# @>   ANM_sensitivity-chain: 0.118
# @>                  BLOSUM: 0.058
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_noPfam - FEATURE LEFT OUT: BLOSUM
# @> 171 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.841   AUPRC = 0.899   OOB score = 0.795
# @> CV iteration # 2:   AUROC = 0.842   AUPRC = 0.908   OOB score = 0.793
# @> CV iteration # 3:   AUROC = 0.847   AUPRC = 0.909   OOB score = 0.793
# @> CV iteration # 4:   AUROC = 0.837   AUPRC = 0.899   OOB score = 0.795
# @> CV iteration # 5:   AUROC = 0.842   AUPRC = 0.906   OOB score = 0.795
# @> CV iteration # 6:   AUROC = 0.840   AUPRC = 0.905   OOB score = 0.795
# @> CV iteration # 7:   AUROC = 0.836   AUPRC = 0.899   OOB score = 0.795
# @> CV iteration # 8:   AUROC = 0.856   AUPRC = 0.916   OOB score = 0.795
# @> CV iteration # 9:   AUROC = 0.840   AUPRC = 0.904   OOB score = 0.795
# @> CV iteration #10:   AUROC = 0.838   AUPRC = 0.902   OOB score = 0.793
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20190
# @> fraction of positives:   0.669
# @> mean AUROC:              0.842
# @> mean AUPRC:              0.905
# @> mean OOB score:          0.795
# @> optimal cutoff*:         0.678 +/- 0.035
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.193
# @>              Delta_PSIC: 0.258
# @>                    SASA: 0.099
# @>           ANM_MSF-chain: 0.109
# @> ANM_effectiveness-chain: 0.114
# @>   ANM_sensitivity-chain: 0.108
# @>         stiffness-chain: 0.118
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: wt_PSIC
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.856   AUPRC = 0.934   OOB score = 0.831
# @> CV iteration # 2:   AUROC = 0.837   AUPRC = 0.923   OOB score = 0.830
# @> CV iteration # 3:   AUROC = 0.865   AUPRC = 0.940   OOB score = 0.831
# @> CV iteration # 4:   AUROC = 0.870   AUPRC = 0.945   OOB score = 0.832
# @> CV iteration # 5:   AUROC = 0.830   AUPRC = 0.930   OOB score = 0.833
# @> CV iteration # 6:   AUROC = 0.856   AUPRC = 0.935   OOB score = 0.830
# @> CV iteration # 7:   AUROC = 0.847   AUPRC = 0.932   OOB score = 0.833
# @> CV iteration # 8:   AUROC = 0.870   AUPRC = 0.945   OOB score = 0.829
# @> CV iteration # 9:   AUROC = 0.847   AUPRC = 0.934   OOB score = 0.830
# @> CV iteration #10:   AUROC = 0.839   AUPRC = 0.925   OOB score = 0.833
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.851
# @> mean AUPRC:              0.934
# @> mean OOB score:          0.831
# @> optimal cutoff*:         0.754 +/- 0.036
# @> (* argmax of Youden's index)
# @> feature importances:
# @>              Delta_PSIC: 0.172
# @>                    SASA: 0.075
# @>           ANM_MSF-chain: 0.079
# @> ANM_effectiveness-chain: 0.087
# @>   ANM_sensitivity-chain: 0.080
# @>         stiffness-chain: 0.084
# @>                 entropy: 0.103
# @>               ranked_MI: 0.076
# @>                  BLOSUM: 0.042
# @>      EVmut-DeltaE_epist: 0.202
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: Delta_PSIC
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.861   AUPRC = 0.938   OOB score = 0.832
# @> CV iteration # 2:   AUROC = 0.851   AUPRC = 0.931   OOB score = 0.831
# @> CV iteration # 3:   AUROC = 0.871   AUPRC = 0.947   OOB score = 0.832
# @> CV iteration # 4:   AUROC = 0.873   AUPRC = 0.946   OOB score = 0.831
# @> CV iteration # 5:   AUROC = 0.837   AUPRC = 0.934   OOB score = 0.834
# @> CV iteration # 6:   AUROC = 0.861   AUPRC = 0.942   OOB score = 0.831
# @> CV iteration # 7:   AUROC = 0.858   AUPRC = 0.941   OOB score = 0.833
# @> CV iteration # 8:   AUROC = 0.872   AUPRC = 0.946   OOB score = 0.831
# @> CV iteration # 9:   AUROC = 0.849   AUPRC = 0.936   OOB score = 0.831
# @> CV iteration #10:   AUROC = 0.845   AUPRC = 0.930   OOB score = 0.833
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.857
# @> mean AUPRC:              0.939
# @> mean OOB score:          0.832
# @> optimal cutoff*:         0.742 +/- 0.037
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.148
# @>                    SASA: 0.074
# @>           ANM_MSF-chain: 0.079
# @> ANM_effectiveness-chain: 0.087
# @>   ANM_sensitivity-chain: 0.081
# @>         stiffness-chain: 0.085
# @>                 entropy: 0.101
# @>               ranked_MI: 0.076
# @>                  BLOSUM: 0.050
# @>      EVmut-DeltaE_epist: 0.218
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: SASA
# @> 7209 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.869   AUPRC = 0.939   OOB score = 0.831
# @> CV iteration # 2:   AUROC = 0.863   AUPRC = 0.938   OOB score = 0.831
# @> CV iteration # 3:   AUROC = 0.828   AUPRC = 0.924   OOB score = 0.833
# @> CV iteration # 4:   AUROC = 0.871   AUPRC = 0.946   OOB score = 0.831
# @> CV iteration # 5:   AUROC = 0.843   AUPRC = 0.935   OOB score = 0.833
# @> CV iteration # 6:   AUROC = 0.859   AUPRC = 0.941   OOB score = 0.833
# @> CV iteration # 7:   AUROC = 0.845   AUPRC = 0.928   OOB score = 0.832
# @> CV iteration # 8:   AUROC = 0.855   AUPRC = 0.934   OOB score = 0.831
# @> CV iteration # 9:   AUROC = 0.862   AUPRC = 0.940   OOB score = 0.831
# @> CV iteration #10:   AUROC = 0.841   AUPRC = 0.931   OOB score = 0.833
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13152
# @> fraction of positives:   0.746
# @> mean AUROC:              0.853
# @> mean AUPRC:              0.936
# @> mean OOB score:          0.832
# @> optimal cutoff*:         0.733 +/- 0.041
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.125
# @>              Delta_PSIC: 0.157
# @>           ANM_MSF-chain: 0.077
# @> ANM_effectiveness-chain: 0.083
# @>   ANM_sensitivity-chain: 0.078
# @>         stiffness-chain: 0.083
# @>                 entropy: 0.095
# @>               ranked_MI: 0.073
# @>                  BLOSUM: 0.040
# @>      EVmut-DeltaE_epist: 0.188
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: ANM_MSF-chain
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.860   AUPRC = 0.937   OOB score = 0.833
# @> CV iteration # 2:   AUROC = 0.839   AUPRC = 0.922   OOB score = 0.831
# @> CV iteration # 3:   AUROC = 0.866   AUPRC = 0.942   OOB score = 0.831
# @> CV iteration # 4:   AUROC = 0.869   AUPRC = 0.944   OOB score = 0.830
# @> CV iteration # 5:   AUROC = 0.833   AUPRC = 0.930   OOB score = 0.834
# @> CV iteration # 6:   AUROC = 0.856   AUPRC = 0.939   OOB score = 0.831
# @> CV iteration # 7:   AUROC = 0.848   AUPRC = 0.932   OOB score = 0.833
# @> CV iteration # 8:   AUROC = 0.869   AUPRC = 0.943   OOB score = 0.832
# @> CV iteration # 9:   AUROC = 0.848   AUPRC = 0.935   OOB score = 0.832
# @> CV iteration #10:   AUROC = 0.839   AUPRC = 0.926   OOB score = 0.833
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.853
# @> mean AUPRC:              0.935
# @> mean OOB score:          0.832
# @> optimal cutoff*:         0.741 +/- 0.042
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.124
# @>              Delta_PSIC: 0.158
# @>                    SASA: 0.072
# @> ANM_effectiveness-chain: 0.086
# @>   ANM_sensitivity-chain: 0.081
# @>         stiffness-chain: 0.084
# @>                 entropy: 0.094
# @>               ranked_MI: 0.074
# @>                  BLOSUM: 0.040
# @>      EVmut-DeltaE_epist: 0.187
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: ANM_effectiveness-chain
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.854   AUPRC = 0.932   OOB score = 0.831
# @> CV iteration # 2:   AUROC = 0.837   AUPRC = 0.922   OOB score = 0.829
# @> CV iteration # 3:   AUROC = 0.865   AUPRC = 0.941   OOB score = 0.831
# @> CV iteration # 4:   AUROC = 0.864   AUPRC = 0.940   OOB score = 0.830
# @> CV iteration # 5:   AUROC = 0.830   AUPRC = 0.927   OOB score = 0.832
# @> CV iteration # 6:   AUROC = 0.854   AUPRC = 0.939   OOB score = 0.830
# @> CV iteration # 7:   AUROC = 0.844   AUPRC = 0.931   OOB score = 0.831
# @> CV iteration # 8:   AUROC = 0.872   AUPRC = 0.945   OOB score = 0.830
# @> CV iteration # 9:   AUROC = 0.844   AUPRC = 0.934   OOB score = 0.832
# @> CV iteration #10:   AUROC = 0.835   AUPRC = 0.924   OOB score = 0.832
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.850
# @> mean AUPRC:              0.934
# @> mean OOB score:          0.831
# @> optimal cutoff*:         0.751 +/- 0.041
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.126
# @>              Delta_PSIC: 0.158
# @>                    SASA: 0.073
# @>           ANM_MSF-chain: 0.078
# @>   ANM_sensitivity-chain: 0.085
# @>         stiffness-chain: 0.081
# @>                 entropy: 0.095
# @>               ranked_MI: 0.075
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.188
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: ANM_sensitivity-chain
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.857   AUPRC = 0.935   OOB score = 0.832
# @> CV iteration # 2:   AUROC = 0.837   AUPRC = 0.922   OOB score = 0.830
# @> CV iteration # 3:   AUROC = 0.865   AUPRC = 0.942   OOB score = 0.833
# @> CV iteration # 4:   AUROC = 0.865   AUPRC = 0.942   OOB score = 0.831
# @> CV iteration # 5:   AUROC = 0.827   AUPRC = 0.927   OOB score = 0.832
# @> CV iteration # 6:   AUROC = 0.855   AUPRC = 0.938   OOB score = 0.832
# @> CV iteration # 7:   AUROC = 0.845   AUPRC = 0.931   OOB score = 0.831
# @> CV iteration # 8:   AUROC = 0.872   AUPRC = 0.946   OOB score = 0.831
# @> CV iteration # 9:   AUROC = 0.848   AUPRC = 0.935   OOB score = 0.832
# @> CV iteration #10:   AUROC = 0.837   AUPRC = 0.926   OOB score = 0.833
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.851
# @> mean AUPRC:              0.934
# @> mean OOB score:          0.832
# @> optimal cutoff*:         0.743 +/- 0.034
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.125
# @>              Delta_PSIC: 0.159
# @>                    SASA: 0.072
# @>           ANM_MSF-chain: 0.078
# @> ANM_effectiveness-chain: 0.089
# @>         stiffness-chain: 0.082
# @>                 entropy: 0.094
# @>               ranked_MI: 0.074
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.186
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: stiffness-chain
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.857   AUPRC = 0.936   OOB score = 0.830
# @> CV iteration # 2:   AUROC = 0.836   AUPRC = 0.920   OOB score = 0.830
# @> CV iteration # 3:   AUROC = 0.866   AUPRC = 0.943   OOB score = 0.830
# @> CV iteration # 4:   AUROC = 0.866   AUPRC = 0.941   OOB score = 0.830
# @> CV iteration # 5:   AUROC = 0.825   AUPRC = 0.925   OOB score = 0.834
# @> CV iteration # 6:   AUROC = 0.853   AUPRC = 0.937   OOB score = 0.831
# @> CV iteration # 7:   AUROC = 0.843   AUPRC = 0.929   OOB score = 0.829
# @> CV iteration # 8:   AUROC = 0.869   AUPRC = 0.942   OOB score = 0.829
# @> CV iteration # 9:   AUROC = 0.844   AUPRC = 0.930   OOB score = 0.830
# @> CV iteration #10:   AUROC = 0.836   AUPRC = 0.926   OOB score = 0.832
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.849
# @> mean AUPRC:              0.933
# @> mean OOB score:          0.831
# @> optimal cutoff*:         0.761 +/- 0.031
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.125
# @>              Delta_PSIC: 0.159
# @>                    SASA: 0.073
# @>           ANM_MSF-chain: 0.080
# @> ANM_effectiveness-chain: 0.084
# @>   ANM_sensitivity-chain: 0.079
# @>                 entropy: 0.095
# @>               ranked_MI: 0.074
# @>                  BLOSUM: 0.040
# @>      EVmut-DeltaE_epist: 0.189
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: entropy
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.861   AUPRC = 0.936   OOB score = 0.832
# @> CV iteration # 2:   AUROC = 0.839   AUPRC = 0.923   OOB score = 0.832
# @> CV iteration # 3:   AUROC = 0.864   AUPRC = 0.940   OOB score = 0.832
# @> CV iteration # 4:   AUROC = 0.867   AUPRC = 0.942   OOB score = 0.832
# @> CV iteration # 5:   AUROC = 0.828   AUPRC = 0.928   OOB score = 0.833
# @> CV iteration # 6:   AUROC = 0.858   AUPRC = 0.938   OOB score = 0.832
# @> CV iteration # 7:   AUROC = 0.845   AUPRC = 0.929   OOB score = 0.833
# @> CV iteration # 8:   AUROC = 0.872   AUPRC = 0.944   OOB score = 0.832
# @> CV iteration # 9:   AUROC = 0.845   AUPRC = 0.929   OOB score = 0.832
# @> CV iteration #10:   AUROC = 0.842   AUPRC = 0.928   OOB score = 0.835
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.852
# @> mean AUPRC:              0.934
# @> mean OOB score:          0.832
# @> optimal cutoff*:         0.741 +/- 0.049
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.130
# @>              Delta_PSIC: 0.160
# @>                    SASA: 0.074
# @>           ANM_MSF-chain: 0.077
# @> ANM_effectiveness-chain: 0.086
# @>   ANM_sensitivity-chain: 0.080
# @>         stiffness-chain: 0.084
# @>               ranked_MI: 0.075
# @>                  BLOSUM: 0.042
# @>      EVmut-DeltaE_epist: 0.192
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: ranked_MI
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.860   AUPRC = 0.936   OOB score = 0.831
# @> CV iteration # 2:   AUROC = 0.841   AUPRC = 0.923   OOB score = 0.832
# @> CV iteration # 3:   AUROC = 0.864   AUPRC = 0.940   OOB score = 0.834
# @> CV iteration # 4:   AUROC = 0.871   AUPRC = 0.945   OOB score = 0.832
# @> CV iteration # 5:   AUROC = 0.835   AUPRC = 0.931   OOB score = 0.835
# @> CV iteration # 6:   AUROC = 0.860   AUPRC = 0.941   OOB score = 0.832
# @> CV iteration # 7:   AUROC = 0.849   AUPRC = 0.934   OOB score = 0.834
# @> CV iteration # 8:   AUROC = 0.874   AUPRC = 0.945   OOB score = 0.831
# @> CV iteration # 9:   AUROC = 0.846   AUPRC = 0.931   OOB score = 0.832
# @> CV iteration #10:   AUROC = 0.840   AUPRC = 0.925   OOB score = 0.834
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.854
# @> mean AUPRC:              0.935
# @> mean OOB score:          0.833
# @> optimal cutoff*:         0.741 +/- 0.038
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.126
# @>              Delta_PSIC: 0.157
# @>                    SASA: 0.072
# @>           ANM_MSF-chain: 0.077
# @> ANM_effectiveness-chain: 0.085
# @>   ANM_sensitivity-chain: 0.079
# @>         stiffness-chain: 0.082
# @>                 entropy: 0.095
# @>                  BLOSUM: 0.040
# @>      EVmut-DeltaE_epist: 0.188
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: BLOSUM
# @> 7328 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.863   AUPRC = 0.939   OOB score = 0.831
# @> CV iteration # 2:   AUROC = 0.841   AUPRC = 0.924   OOB score = 0.831
# @> CV iteration # 3:   AUROC = 0.869   AUPRC = 0.945   OOB score = 0.833
# @> CV iteration # 4:   AUROC = 0.869   AUPRC = 0.945   OOB score = 0.831
# @> CV iteration # 5:   AUROC = 0.834   AUPRC = 0.932   OOB score = 0.834
# @> CV iteration # 6:   AUROC = 0.859   AUPRC = 0.940   OOB score = 0.831
# @> CV iteration # 7:   AUROC = 0.851   AUPRC = 0.935   OOB score = 0.832
# @> CV iteration # 8:   AUROC = 0.875   AUPRC = 0.947   OOB score = 0.832
# @> CV iteration # 9:   AUROC = 0.850   AUPRC = 0.937   OOB score = 0.834
# @> CV iteration #10:   AUROC = 0.844   AUPRC = 0.930   OOB score = 0.831
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   13033
# @> fraction of positives:   0.746
# @> mean AUROC:              0.855
# @> mean AUPRC:              0.937
# @> mean OOB score:          0.832
# @> optimal cutoff*:         0.767 +/- 0.035
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.122
# @>              Delta_PSIC: 0.158
# @>                    SASA: 0.068
# @>           ANM_MSF-chain: 0.073
# @> ANM_effectiveness-chain: 0.081
# @>   ANM_sensitivity-chain: 0.075
# @>         stiffness-chain: 0.078
# @>                 entropy: 0.090
# @>               ranked_MI: 0.070
# @>      EVmut-DeltaE_epist: 0.187
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> VERSION: v2_EVmut - FEATURE LEFT OUT: EVmut-DeltaE_epist
# @> 3918 out of 20361 cases ignored with missing features.
# @> CV iteration # 1:   AUROC = 0.863   AUPRC = 0.924   OOB score = 0.810
# @> CV iteration # 2:   AUROC = 0.864   AUPRC = 0.924   OOB score = 0.809
# @> CV iteration # 3:   AUROC = 0.843   AUPRC = 0.914   OOB score = 0.812
# @> CV iteration # 4:   AUROC = 0.870   AUPRC = 0.930   OOB score = 0.811
# @> CV iteration # 5:   AUROC = 0.857   AUPRC = 0.925   OOB score = 0.813
# @> CV iteration # 6:   AUROC = 0.851   AUPRC = 0.920   OOB score = 0.813
# @> CV iteration # 7:   AUROC = 0.861   AUPRC = 0.924   OOB score = 0.811
# @> CV iteration # 8:   AUROC = 0.858   AUPRC = 0.924   OOB score = 0.811
# @> CV iteration # 9:   AUROC = 0.845   AUPRC = 0.909   OOB score = 0.811
# @> CV iteration #10:   AUROC = 0.850   AUPRC = 0.916   OOB score = 0.811
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16443
# @> fraction of positives:   0.690
# @> mean AUROC:              0.856
# @> mean AUPRC:              0.921
# @> mean OOB score:          0.811
# @> optimal cutoff*:         0.706 +/- 0.030
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.152
# @>              Delta_PSIC: 0.203
# @>                    SASA: 0.075
# @>           ANM_MSF-chain: 0.082
# @> ANM_effectiveness-chain: 0.086
# @>   ANM_sensitivity-chain: 0.079
# @>         stiffness-chain: 0.090
# @>                 entropy: 0.108
# @>               ranked_MI: 0.076
# @>                  BLOSUM: 0.049
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @>
# @> Logging stopped at 2019-05-27 11:22:20.923041
# @> Closing logfile: results/LOFO_analysis.log

# %%
# recover precomputed results
LOFO_summaries = pickle.load(open('results/LOFO_summaries.pkl', 'rb'))

# %%
abbrv_2 = {
    'ANM_MSF-chain': 'MSF',
    'ANM_effectiveness-chain': 'eff',
    'ANM_sensitivity-chain': 'sens',
    'BLOSUM': 'BLSM',
    'Delta_PSIC': 'ΔPSIC', 
    'EVmut-DeltaE_epist': 'EVm.ΔE',
    'SASA': 'SASA',
    'entropy': 'entropy',
    'ranked_MI': 'MI',
    'stiffness-chain': 'stiff',
    'wt_PSIC': 'wtPSIC',
    'v2': 'Rhapsody (full)',
    'v2_noPfam': 'Rhapsody (redux)',
    'v2_EVmut': 'Rhapsody+EVmutation',
}

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

for i, (version, d) in enumerate(LOFO_summaries.items()):
    
    featset = featsets[version]
    n = len(featset)
    
    data = np.zeros((n, 3))
    for j, f in enumerate(featset):
        data[j] = [d[f][x] for x in ('mean AUROC', 'mean AUPRC', 'mean OOB score')]

    ax = axes[i]
    ax.set_title(abbrv_2[version])
    
    for p, c in [('AUROC', 'C0'), ('AUPRC', 'C1'), ('OOB score', 'C7')]:
        ax.axhline(y=RF_training_summaries[version][f'mean {p}'], c=c, ls='--', alpha=.5, zorder=0)
    
    # bar plots
    X = np.arange(n)

    h0 = ax.bar(X + 0.2, data[:,1], color='C1', width=.4, edgecolor='w', label='AUPRC')
    h1 = ax.bar(X + 0.3, data[:,2], color='C7', width=.4, edgecolor='w', label='OOB score')
    h2 = ax.bar(X + 0.0, data[:,0], color='C0', width=.4, edgecolor='w', label='AUROC')

    handles = [h2, h0, h1]
    ax.legend(handles, [h.get_label() for h in handles], handlelength=1, labelspacing=.3)

    ax.set_xlim((-.5, n-0.1))
    ax.set_ylim((0.75,1))

    ax.set_xticks(range(n))
    labels = [abbrv_2[f] for f in featsets[version]]
    ax.set_xticklabels(labels, rotation='vertical')

plt.tight_layout()
fig.savefig('figures/LOFO.png',  dpi=300)

# %% [markdown]
# ## Correlation between features

# %%
from scipy.stats import spearmanr

featset = featsets['v2_EVmut']

X = ID[featset]
sel = [~np.isnan(np.sum([x for x in r])) for r in X]
X = X[sel]
X = np.array([[np.float32(x) for x in v] for v in X])

correlations = spearmanr(X)

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
    
m = correlations[0]

im = ax.imshow(abs(m), cmap='hot', vmin=0, vmax=1)
ax.set_title('correlation between features')

# text annotations
n = m.shape[0]
for i in range(n):
    for j in range(n):
        if i==j: continue
        text = ax.text(j, i, f'{m[i, j]:.2f}', ha="center", va="center", 
                       color="w" if abs(m[i, j])<.5 else "k", fontsize='x-small')

labels = [abbrv_2[f] for f in featsets['v2_EVmut']]
ax.set_yticks(range(n))
ax.set_yticklabels(labels)
ax.set_xticks(range(n))
ax.set_xticklabels(labels, rotation='vertical')
    
plt.tight_layout()
fig.savefig('figures/correlation_btw_features.png', dpi=300)

# %% [markdown]
# ## Feature distributions

# %%
from matplotlib.patches import Patch

fig, axes = plt.subplots(4, 3, figsize=(10, 12))

classes = {
    'del' : ID[ID['true_label']==1],
    'neu' : ID[ID['true_label']==0]
}

for n, feature in enumerate(featsets['v2_EVmut']):
    
    ax = axes[int(n/3), n%3]
    
    data = {}
    for cl in ('del', 'neu'):
        d = classes[cl][feature]
        data[cl] = d[~np.isnan(d)]

    title = abbrv[feature]

    if feature.startswith('ANM'):
        # use log-log scale
        title = f'log({title})'
        ax.set_yscale('log')
        for k in data:
            data[k] = np.log(data[k])
 
    ax.set_title(title)
    
    n, bins, patches = ax.hist(data['del'], bins='fd', color='C3', alpha=.9, density=True)
    ax.hist(data['neu'], bins=bins, color='C0', alpha=.8, density=True)

axes[3,2].axis('off')
legend_elements = [Patch(facecolor='C3', label='deleterious SAVs'), 
                   Patch(facecolor='C0', label='neutral SAVs')]
axes[3,2].legend(handles=legend_elements, loc='upper left')
        
fig.tight_layout()
fig.savefig('figures/feat_distributions.png', dpi=300)
