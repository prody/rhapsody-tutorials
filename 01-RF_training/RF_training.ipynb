# %% [markdown]
# # Training of Random Forest classifiers
#
# In the following, we train different versions of the Rhapsody classifier and compare their accuracy. Each version is trained on the Integrated Dataset of human missense variants and evaluated through 10-fold cross-validation.
#
# More specifically, we considered:
# * different subsets of features,
# * different subsets of the training dataset,
# * different classifier's hyperparameters

# %%
import sys, os
import pickle
import numpy as np
from glob import glob

# %%
# Insert here path to Rhapsody folder
sys.path.insert(0, '/home/lponzoni/Scratch/028-RHAPSODY-git/rhapsody')

# %%
from rhapsody import *

# %% [markdown]
# ## Importing the training dataset
#
# The Integrated Dataset used for training is made available as a NumPy structured array containing all precomputed features, as well as true labels and other info (e.g. PDB lengths).

# %%
ID = pickle.load(open('Integrated_Dataset.pkl', 'rb'))

# %%
# array structure
ID.dtype.names
# Out:
# ('SAV_coords',
#  'Uniprot2PDB',
#  'PDB_length',
#  'true_label',
#  'wt_PSIC',
#  'Delta_PSIC',
#  'SASA',
#  'Delta_SASA',
#  'BLOSUM',
#  'GNM_MSF-chain',
#  'GNM_MSF-reduced',
#  'GNM_effectiveness-chain',
#  'GNM_effectiveness-reduced',
#  'GNM_sensitivity-chain',
#  'GNM_sensitivity-reduced',
#  'ANM_MSF-chain',
#  'ANM_MSF-reduced',
#  'ANM_effectiveness-chain',
#  'ANM_effectiveness-reduced',
#  'ANM_sensitivity-chain',
#  'ANM_sensitivity-reduced',
#  'stiffness-chain',
#  'stiffness-reduced',
#  'MBS-chain',
#  'MBS-reduced',
#  'entropy',
#  'ranked_MI',
#  'EVmut-DeltaE_epist',
#  'EVmut-DeltaE_indep',
#  'EVmut-wt_aa_cons',
#  'EVmut-mut_aa_freq')

# %%
# each entry can be accessed by indexing
ID[0]
# Out:
# ('Q96JB6 405 D A', 'Unable to map SAV to PDB', nan, 0, -0.924, 2.234, nan, nan, -2., nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 1.469, 0.9847, -6.859, -2.213, 0.5493, 0.07133)

# %%
# size of the training dataset
len(ID)
# Out:
# 92108

# %%
# number of entries with an associated PDB structure
len(ID[~np.isnan(ID['PDB_length'])])
# Out:
# 28010

# %% [markdown]
# ## Cross-validation with various classification schemes
#
# We assess, through 10-fold cross-validation, the effect of considering different combinations of features and training datasets.
# In particular, we compare performances when using:
# * different subsets of the training dataset, obtained by selecting those cases where PDB structures were larger than *n* residues
# * 4 different feature sets, including one reproducing version 1 of the method (RAPSODY)
# * **GNM** vs **ANM** features
# * ENM features computed with and without the inclusion of *enviromental* effects (**reduced** vs **chain** model), i.e. the presence of other chains in the PDB structure

# %%
os.mkdir('results')

# %%
# this cell requires ~3.5 hours to complete

from prody import LOGGER
LOGGER.start('results/RF_training.log')

CV_summaries = {}

if os.path.isfile('results/CV-summaries.pkl'):
    print('A pickle containing precomputed training results have been found.')
    print('Please delete it if you wish to run the training again.')
else:
    for min_num_res in [0, 100, 150, 200, 300, 400, 500, 600]:
        # compute subset of the training dataset
        ID_subset = ID[ ~np.isnan(ID['PDB_length']) ]
        ID_subset = ID_subset[ ID_subset['PDB_length'] >= min_num_res ]
        
        # loop over different classification schemes
        for ENM in ['GNM', 'ANM']:
            for model in ['chain', 'reduced']:
                for version in ['v2', 'v2_noPfam', 'v2_EVmut', 'v1']:

                    # select feature set (+ true label)
                    if version == 'v2':
                        # full classifier
                        featset = ['SAV_coords', 'true_label', 
                                   'wt_PSIC', 'Delta_PSIC', 'SASA', 
                                   f'{ENM}_MSF-{model}',
                                   f'{ENM}_effectiveness-{model}',
                                   f'{ENM}_sensitivity-{model}',
                                   f'stiffness-{model}',
                                   'entropy', 'ranked_MI', 'BLOSUM']
                    elif version == 'v2_noPfam':
                        # reduced classifier
                        featset = ['SAV_coords', 'true_label',
                                   'wt_PSIC', 'Delta_PSIC', 'SASA', 
                                   f'{ENM}_MSF-{model}',
                                   f'{ENM}_effectiveness-{model}',
                                   f'{ENM}_sensitivity-{model}',
                                   f'stiffness-{model}',
                                   'BLOSUM']
                    elif version == 'v2_EVmut':
                        # full classifier + EVmutation epistatic score
                        featset = ['SAV_coords', 'true_label',
                                   'wt_PSIC', 'Delta_PSIC', 'SASA', 
                                   f'{ENM}_MSF-{model}',
                                   f'{ENM}_effectiveness-{model}',
                                   f'{ENM}_sensitivity-{model}',
                                   f'stiffness-{model}',
                                   'entropy', 'ranked_MI', 'BLOSUM',
                                   'EVmut-DeltaE_epist']
                    elif version == 'v1' and ENM == 'GNM' and model == 'chain':
                        # classifier as in version 1 of Rhapsody (RAPSODY)
                        # NB: RAPSODY used a combination of GNM/ANM features, which
                        # we reproduce here for the sake of comparison
                        featset = ['SAV_coords', 'true_label', 
                                   'wt_PSIC', 'Delta_PSIC', 'SASA', 
                                   'GNM_MSF-chain', 
                                   'ANM_effectiveness-chain', 
                                   'ANM_sensitivity-chain',
                                   'stiffness-chain']
                    else:
                        continue

                    if version == 'v1':
                        scheme = f'{min_num_res}-v1'
                    else:
                        scheme = f'{min_num_res}-{ENM}-{model}-{version}'
                        
                    LOGGER.info(f'CLASSIFICATION SCHEME: {scheme}')

                    # create folder
                    folder = f'results/clsf_scheme-{scheme}'
                    os.mkdir(folder)
                    
                    # train the classifier
                    clsf = trainRFclassifier(ID_subset[featset])

                    # store summary from cross-validation into a dictionary
                    CV_summaries[scheme] = clsf['CV summary']

                    # move figures into folder
                    for file in glob('*png'):
                        os.rename(file, os.path.join(folder, file))

                    # we'll only keep classifiers trained with the 150 min_num_res requirement
                    clsf_file = 'trained_classifier.pkl'
                    if min_num_res == 150:
                        os.rename(clsf_file, os.path.join(folder, clsf_file))
                    else:
                        os.remove(clsf_file)
                    
                    LOGGER.info('')
                    
    # store all cross-validation results into a pickle
    pickle.dump(CV_summaries, open('results/CV_summaries.pkl', 'wb'))

LOGGER.close('results/RF_training.log')
# Out:
# @> Logging into file: results/RF_training.log
# @> Logging started at 2019-02-06 19:15:20.852476
# @> CLASSIFICATION SCHEME: 0-GNM-chain-v2
# @> 5955 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.839   OOB score = 0.817
# @> CV iteration # 2:    ROC-AUC = 0.851   OOB score = 0.817
# @> CV iteration # 3:    ROC-AUC = 0.839   OOB score = 0.818
# @> CV iteration # 4:    ROC-AUC = 0.828   OOB score = 0.818
# @> CV iteration # 5:    ROC-AUC = 0.840   OOB score = 0.817
# @> CV iteration # 6:    ROC-AUC = 0.846   OOB score = 0.820
# @> CV iteration # 7:    ROC-AUC = 0.843   OOB score = 0.818
# @> CV iteration # 8:    ROC-AUC = 0.845   OOB score = 0.818
# @> CV iteration # 9:    ROC-AUC = 0.860   OOB score = 0.817
# @> CV iteration #10:    ROC-AUC = 0.851   OOB score = 0.819
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   22055
# @> fraction of positives:   0.731
# @> mean ROC-AUC:            0.844
# @> mean OOB score:          0.818
# @> optimal cutoff*:         0.731 +/- 0.025
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.146
# @>              Delta_PSIC: 0.197
# @>                    SASA: 0.076
# @>           GNM_MSF-chain: 0.086
# @> GNM_effectiveness-chain: 0.083
# @>   GNM_sensitivity-chain: 0.082
# @>         stiffness-chain: 0.085
# @>                 entropy: 0.113
# @>               ranked_MI: 0.081
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.819
# @> feature importances:
# @>                 wt_PSIC: 0.147
# @>              Delta_PSIC: 0.195
# @>                    SASA: 0.076
# @>           GNM_MSF-chain: 0.086
# @> GNM_effectiveness-chain: 0.082
# @>   GNM_sensitivity-chain: 0.082
# @>         stiffness-chain: 0.085
# @>                 entropy: 0.113
# @>               ranked_MI: 0.081
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-GNM-chain-v2_noPfam
# @> 315 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.831   OOB score = 0.808
# @> CV iteration # 2:    ROC-AUC = 0.818   OOB score = 0.806
# @> CV iteration # 3:    ROC-AUC = 0.842   OOB score = 0.805
# @> CV iteration # 4:    ROC-AUC = 0.821   OOB score = 0.806
# @> CV iteration # 5:    ROC-AUC = 0.837   OOB score = 0.803
# @> CV iteration # 6:    ROC-AUC = 0.824   OOB score = 0.806
# @> CV iteration # 7:    ROC-AUC = 0.832   OOB score = 0.805
# @> CV iteration # 8:    ROC-AUC = 0.846   OOB score = 0.805
# @> CV iteration # 9:    ROC-AUC = 0.833   OOB score = 0.803
# @> CV iteration #10:    ROC-AUC = 0.837   OOB score = 0.806
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   27695
# @> fraction of positives:   0.713
# @> mean ROC-AUC:            0.832
# @> mean OOB score:          0.805
# @> optimal cutoff*:         0.705 +/- 0.034
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.180
# @>              Delta_PSIC: 0.229
# @>                    SASA: 0.096
# @>           GNM_MSF-chain: 0.111
# @> GNM_effectiveness-chain: 0.108
# @>   GNM_sensitivity-chain: 0.106
# @>         stiffness-chain: 0.113
# @>                  BLOSUM: 0.057
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.807
# @> feature importances:
# @>                 wt_PSIC: 0.181
# @>              Delta_PSIC: 0.228
# @>                    SASA: 0.096
# @>           GNM_MSF-chain: 0.111
# @> GNM_effectiveness-chain: 0.108
# @>   GNM_sensitivity-chain: 0.106
# @>         stiffness-chain: 0.113
# @>                  BLOSUM: 0.057
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-GNM-chain-v2_EVmut
# @> 11472 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.857   OOB score = 0.844
# @> CV iteration # 2:    ROC-AUC = 0.836   OOB score = 0.843
# @> CV iteration # 3:    ROC-AUC = 0.863   OOB score = 0.844
# @> CV iteration # 4:    ROC-AUC = 0.853   OOB score = 0.842
# @> CV iteration # 5:    ROC-AUC = 0.843   OOB score = 0.846
# @> CV iteration # 6:    ROC-AUC = 0.853   OOB score = 0.845
# @> CV iteration # 7:    ROC-AUC = 0.856   OOB score = 0.846
# @> CV iteration # 8:    ROC-AUC = 0.853   OOB score = 0.846
# @> CV iteration # 9:    ROC-AUC = 0.842   OOB score = 0.844
# @> CV iteration #10:    ROC-AUC = 0.862   OOB score = 0.843
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16538
# @> fraction of positives:   0.780
# @> mean ROC-AUC:            0.852
# @> mean OOB score:          0.844
# @> optimal cutoff*:         0.794 +/- 0.032
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.117
# @>              Delta_PSIC: 0.146
# @>                    SASA: 0.067
# @>           GNM_MSF-chain: 0.074
# @> GNM_effectiveness-chain: 0.074
# @>   GNM_sensitivity-chain: 0.073
# @>         stiffness-chain: 0.070
# @>                 entropy: 0.091
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.179
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.845
# @> feature importances:
# @>                 wt_PSIC: 0.119
# @>              Delta_PSIC: 0.143
# @>                    SASA: 0.066
# @>           GNM_MSF-chain: 0.074
# @> GNM_effectiveness-chain: 0.074
# @>   GNM_sensitivity-chain: 0.073
# @>         stiffness-chain: 0.070
# @>                 entropy: 0.090
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.180
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-v1
# @> 313 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.826   OOB score = 0.804
# @> CV iteration # 2:    ROC-AUC = 0.836   OOB score = 0.801
# @> CV iteration # 3:    ROC-AUC = 0.838   OOB score = 0.801
# @> CV iteration # 4:    ROC-AUC = 0.834   OOB score = 0.803
# @> CV iteration # 5:    ROC-AUC = 0.830   OOB score = 0.802
# @> CV iteration # 6:    ROC-AUC = 0.835   OOB score = 0.802
# @> CV iteration # 7:    ROC-AUC = 0.840   OOB score = 0.803
# @> CV iteration # 8:    ROC-AUC = 0.827   OOB score = 0.803
# @> CV iteration # 9:    ROC-AUC = 0.838   OOB score = 0.801
# @> CV iteration #10:    ROC-AUC = 0.831   OOB score = 0.801
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   27697
# @> fraction of positives:   0.713
# @> mean ROC-AUC:            0.833
# @> mean OOB score:          0.802
# @> optimal cutoff*:         0.717 +/- 0.023
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.186
# @>              Delta_PSIC: 0.251
# @>                    SASA: 0.099
# @>           GNM_MSF-chain: 0.118
# @> ANM_effectiveness-chain: 0.116
# @>   ANM_sensitivity-chain: 0.109
# @>         stiffness-chain: 0.121
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.803
# @> feature importances:
# @>                 wt_PSIC: 0.185
# @>              Delta_PSIC: 0.251
# @>                    SASA: 0.100
# @>           GNM_MSF-chain: 0.118
# @> ANM_effectiveness-chain: 0.116
# @>   ANM_sensitivity-chain: 0.109
# @>         stiffness-chain: 0.121
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-GNM-reduced-v2
# @> 5978 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.844   OOB score = 0.813
# @> CV iteration # 2:    ROC-AUC = 0.834   OOB score = 0.815
# @> CV iteration # 3:    ROC-AUC = 0.850   OOB score = 0.813
# @> CV iteration # 4:    ROC-AUC = 0.834   OOB score = 0.816
# @> CV iteration # 5:    ROC-AUC = 0.842   OOB score = 0.816
# @> CV iteration # 6:    ROC-AUC = 0.836   OOB score = 0.815
# @> CV iteration # 7:    ROC-AUC = 0.832   OOB score = 0.815
# @> CV iteration # 8:    ROC-AUC = 0.844   OOB score = 0.813
# @> CV iteration # 9:    ROC-AUC = 0.839   OOB score = 0.814
# @> CV iteration #10:    ROC-AUC = 0.852   OOB score = 0.814
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   22032
# @> fraction of positives:   0.731
# @> mean ROC-AUC:            0.840
# @> mean OOB score:          0.814
# @> optimal cutoff*:         0.720 +/- 0.027
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.149
# @>              Delta_PSIC: 0.198
# @>                    SASA: 0.078
# @>         GNM_MSF-reduced: 0.084
# @> GNM_effectiveness-reduced: 0.078
# @> GNM_sensitivity-reduced: 0.079
# @>       stiffness-reduced: 0.085
# @>                 entropy: 0.116
# @>               ranked_MI: 0.082
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.815
# @> feature importances:
# @>                 wt_PSIC: 0.148
# @>              Delta_PSIC: 0.199
# @>                    SASA: 0.078
# @>         GNM_MSF-reduced: 0.084
# @> GNM_effectiveness-reduced: 0.078
# @> GNM_sensitivity-reduced: 0.079
# @>       stiffness-reduced: 0.085
# @>                 entropy: 0.117
# @>               ranked_MI: 0.083
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-GNM-reduced-v2_noPfam
# @> 348 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.813   OOB score = 0.802
# @> CV iteration # 2:    ROC-AUC = 0.814   OOB score = 0.802
# @> CV iteration # 3:    ROC-AUC = 0.831   OOB score = 0.800
# @> CV iteration # 4:    ROC-AUC = 0.824   OOB score = 0.803
# @> CV iteration # 5:    ROC-AUC = 0.826   OOB score = 0.800
# @> CV iteration # 6:    ROC-AUC = 0.834   OOB score = 0.801
# @> CV iteration # 7:    ROC-AUC = 0.825   OOB score = 0.801
# @> CV iteration # 8:    ROC-AUC = 0.836   OOB score = 0.801
# @> CV iteration # 9:    ROC-AUC = 0.827   OOB score = 0.800
# @> CV iteration #10:    ROC-AUC = 0.823   OOB score = 0.801
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   27662
# @> fraction of positives:   0.714
# @> mean ROC-AUC:            0.825
# @> mean OOB score:          0.801
# @> optimal cutoff*:         0.707 +/- 0.042
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.183
# @>              Delta_PSIC: 0.232
# @>                    SASA: 0.099
# @>         GNM_MSF-reduced: 0.110
# @> GNM_effectiveness-reduced: 0.104
# @> GNM_sensitivity-reduced: 0.103
# @>       stiffness-reduced: 0.112
# @>                  BLOSUM: 0.057
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.801
# @> feature importances:
# @>                 wt_PSIC: 0.185
# @>              Delta_PSIC: 0.230
# @>                    SASA: 0.099
# @>         GNM_MSF-reduced: 0.110
# @> GNM_effectiveness-reduced: 0.104
# @> GNM_sensitivity-reduced: 0.104
# @>       stiffness-reduced: 0.112
# @>                  BLOSUM: 0.056
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-GNM-reduced-v2_EVmut
# @> 11472 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.849   OOB score = 0.842
# @> CV iteration # 2:    ROC-AUC = 0.837   OOB score = 0.842
# @> CV iteration # 3:    ROC-AUC = 0.841   OOB score = 0.842
# @> CV iteration # 4:    ROC-AUC = 0.854   OOB score = 0.842
# @> CV iteration # 5:    ROC-AUC = 0.848   OOB score = 0.843
# @> CV iteration # 6:    ROC-AUC = 0.841   OOB score = 0.842
# @> CV iteration # 7:    ROC-AUC = 0.839   OOB score = 0.842
# @> CV iteration # 8:    ROC-AUC = 0.840   OOB score = 0.843
# @> CV iteration # 9:    ROC-AUC = 0.849   OOB score = 0.843
# @> CV iteration #10:    ROC-AUC = 0.862   OOB score = 0.841
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16538
# @> fraction of positives:   0.780
# @> mean ROC-AUC:            0.846
# @> mean OOB score:          0.842
# @> optimal cutoff*:         0.780 +/- 0.037
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.118
# @>              Delta_PSIC: 0.148
# @>                    SASA: 0.068
# @>         GNM_MSF-reduced: 0.073
# @> GNM_effectiveness-reduced: 0.068
# @> GNM_sensitivity-reduced: 0.068
# @>       stiffness-reduced: 0.072
# @>                 entropy: 0.093
# @>               ranked_MI: 0.071
# @>                  BLOSUM: 0.042
# @>      EVmut-DeltaE_epist: 0.179
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.842
# @> feature importances:
# @>                 wt_PSIC: 0.116
# @>              Delta_PSIC: 0.148
# @>                    SASA: 0.069
# @>         GNM_MSF-reduced: 0.074
# @> GNM_effectiveness-reduced: 0.068
# @> GNM_sensitivity-reduced: 0.068
# @>       stiffness-reduced: 0.071
# @>                 entropy: 0.093
# @>               ranked_MI: 0.071
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.181
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-ANM-chain-v2
# @> 5953 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.831   OOB score = 0.818
# @> CV iteration # 2:    ROC-AUC = 0.854   OOB score = 0.817
# @> CV iteration # 3:    ROC-AUC = 0.847   OOB score = 0.818
# @> CV iteration # 4:    ROC-AUC = 0.845   OOB score = 0.818
# @> CV iteration # 5:    ROC-AUC = 0.838   OOB score = 0.817
# @> CV iteration # 6:    ROC-AUC = 0.841   OOB score = 0.818
# @> CV iteration # 7:    ROC-AUC = 0.848   OOB score = 0.818
# @> CV iteration # 8:    ROC-AUC = 0.838   OOB score = 0.817
# @> CV iteration # 9:    ROC-AUC = 0.849   OOB score = 0.818
# @> CV iteration #10:    ROC-AUC = 0.853   OOB score = 0.816
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   22057
# @> fraction of positives:   0.731
# @> mean ROC-AUC:            0.844
# @> mean OOB score:          0.818
# @> optimal cutoff*:         0.741 +/- 0.031
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.147
# @>              Delta_PSIC: 0.196
# @>                    SASA: 0.077
# @>           ANM_MSF-chain: 0.083
# @> ANM_effectiveness-chain: 0.085
# @>   ANM_sensitivity-chain: 0.078
# @>         stiffness-chain: 0.088
# @>                 entropy: 0.114
# @>               ranked_MI: 0.081
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.818
# @> feature importances:
# @>                 wt_PSIC: 0.147
# @>              Delta_PSIC: 0.198
# @>                    SASA: 0.077
# @>           ANM_MSF-chain: 0.083
# @> ANM_effectiveness-chain: 0.085
# @>   ANM_sensitivity-chain: 0.078
# @>         stiffness-chain: 0.088
# @>                 entropy: 0.113
# @>               ranked_MI: 0.081
# @>                  BLOSUM: 0.049
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-ANM-chain-v2_noPfam
# @> 313 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.826   OOB score = 0.805
# @> CV iteration # 2:    ROC-AUC = 0.835   OOB score = 0.805
# @> CV iteration # 3:    ROC-AUC = 0.839   OOB score = 0.804
# @> CV iteration # 4:    ROC-AUC = 0.832   OOB score = 0.804
# @> CV iteration # 5:    ROC-AUC = 0.824   OOB score = 0.803
# @> CV iteration # 6:    ROC-AUC = 0.831   OOB score = 0.804
# @> CV iteration # 7:    ROC-AUC = 0.837   OOB score = 0.804
# @> CV iteration # 8:    ROC-AUC = 0.822   OOB score = 0.804
# @> CV iteration # 9:    ROC-AUC = 0.834   OOB score = 0.803
# @> CV iteration #10:    ROC-AUC = 0.837   OOB score = 0.802
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   27697
# @> fraction of positives:   0.713
# @> mean ROC-AUC:            0.832
# @> mean OOB score:          0.804
# @> optimal cutoff*:         0.716 +/- 0.025
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.181
# @>              Delta_PSIC: 0.229
# @>                    SASA: 0.098
# @>           ANM_MSF-chain: 0.109
# @> ANM_effectiveness-chain: 0.109
# @>   ANM_sensitivity-chain: 0.102
# @>         stiffness-chain: 0.115
# @>                  BLOSUM: 0.057
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.805
# @> feature importances:
# @>                 wt_PSIC: 0.182
# @>              Delta_PSIC: 0.227
# @>                    SASA: 0.099
# @>           ANM_MSF-chain: 0.109
# @> ANM_effectiveness-chain: 0.109
# @>   ANM_sensitivity-chain: 0.102
# @>         stiffness-chain: 0.115
# @>                  BLOSUM: 0.057
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-ANM-chain-v2_EVmut
# @> 11470 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.851   OOB score = 0.846
# @> CV iteration # 2:    ROC-AUC = 0.835   OOB score = 0.845
# @> CV iteration # 3:    ROC-AUC = 0.856   OOB score = 0.845
# @> CV iteration # 4:    ROC-AUC = 0.850   OOB score = 0.844
# @> CV iteration # 5:    ROC-AUC = 0.850   OOB score = 0.846
# @> CV iteration # 6:    ROC-AUC = 0.860   OOB score = 0.845
# @> CV iteration # 7:    ROC-AUC = 0.866   OOB score = 0.845
# @> CV iteration # 8:    ROC-AUC = 0.849   OOB score = 0.846
# @> CV iteration # 9:    ROC-AUC = 0.854   OOB score = 0.845
# @> CV iteration #10:    ROC-AUC = 0.852   OOB score = 0.847
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16540
# @> fraction of positives:   0.780
# @> mean ROC-AUC:            0.852
# @> mean OOB score:          0.845
# @> optimal cutoff*:         0.768 +/- 0.039
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.117
# @>              Delta_PSIC: 0.145
# @>                    SASA: 0.068
# @>           ANM_MSF-chain: 0.070
# @> ANM_effectiveness-chain: 0.077
# @>   ANM_sensitivity-chain: 0.070
# @>         stiffness-chain: 0.073
# @>                 entropy: 0.091
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.181
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.846
# @> feature importances:
# @>                 wt_PSIC: 0.116
# @>              Delta_PSIC: 0.143
# @>                    SASA: 0.068
# @>           ANM_MSF-chain: 0.069
# @> ANM_effectiveness-chain: 0.077
# @>   ANM_sensitivity-chain: 0.070
# @>         stiffness-chain: 0.073
# @>                 entropy: 0.090
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.184
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-ANM-reduced-v2
# @> 5978 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.840   OOB score = 0.815
# @> CV iteration # 2:    ROC-AUC = 0.837   OOB score = 0.815
# @> CV iteration # 3:    ROC-AUC = 0.850   OOB score = 0.815
# @> CV iteration # 4:    ROC-AUC = 0.839   OOB score = 0.815
# @> CV iteration # 5:    ROC-AUC = 0.848   OOB score = 0.814
# @> CV iteration # 6:    ROC-AUC = 0.842   OOB score = 0.815
# @> CV iteration # 7:    ROC-AUC = 0.829   OOB score = 0.815
# @> CV iteration # 8:    ROC-AUC = 0.852   OOB score = 0.813
# @> CV iteration # 9:    ROC-AUC = 0.839   OOB score = 0.813
# @> CV iteration #10:    ROC-AUC = 0.857   OOB score = 0.812
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   22032
# @> fraction of positives:   0.731
# @> mean ROC-AUC:            0.843
# @> mean OOB score:          0.814
# @> optimal cutoff*:         0.738 +/- 0.020
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.149
# @>              Delta_PSIC: 0.199
# @>                    SASA: 0.079
# @>         ANM_MSF-reduced: 0.079
# @> ANM_effectiveness-reduced: 0.082
# @> ANM_sensitivity-reduced: 0.077
# @>       stiffness-reduced: 0.087
# @>                 entropy: 0.115
# @>               ranked_MI: 0.082
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.815
# @> feature importances:
# @>                 wt_PSIC: 0.152
# @>              Delta_PSIC: 0.196
# @>                    SASA: 0.079
# @>         ANM_MSF-reduced: 0.079
# @> ANM_effectiveness-reduced: 0.083
# @> ANM_sensitivity-reduced: 0.077
# @>       stiffness-reduced: 0.088
# @>                 entropy: 0.114
# @>               ranked_MI: 0.082
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-ANM-reduced-v2_noPfam
# @> 348 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.820   OOB score = 0.802
# @> CV iteration # 2:    ROC-AUC = 0.810   OOB score = 0.803
# @> CV iteration # 3:    ROC-AUC = 0.838   OOB score = 0.800
# @> CV iteration # 4:    ROC-AUC = 0.826   OOB score = 0.802
# @> CV iteration # 5:    ROC-AUC = 0.831   OOB score = 0.802
# @> CV iteration # 6:    ROC-AUC = 0.836   OOB score = 0.801
# @> CV iteration # 7:    ROC-AUC = 0.830   OOB score = 0.803
# @> CV iteration # 8:    ROC-AUC = 0.840   OOB score = 0.801
# @> CV iteration # 9:    ROC-AUC = 0.832   OOB score = 0.801
# @> CV iteration #10:    ROC-AUC = 0.827   OOB score = 0.802
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   27662
# @> fraction of positives:   0.714
# @> mean ROC-AUC:            0.829
# @> mean OOB score:          0.802
# @> optimal cutoff*:         0.715 +/- 0.025
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.184
# @>              Delta_PSIC: 0.231
# @>                    SASA: 0.100
# @>         ANM_MSF-reduced: 0.104
# @> ANM_effectiveness-reduced: 0.108
# @> ANM_sensitivity-reduced: 0.101
# @>       stiffness-reduced: 0.115
# @>                  BLOSUM: 0.057
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.803
# @> feature importances:
# @>                 wt_PSIC: 0.186
# @>              Delta_PSIC: 0.229
# @>                    SASA: 0.100
# @>         ANM_MSF-reduced: 0.104
# @> ANM_effectiveness-reduced: 0.108
# @> ANM_sensitivity-reduced: 0.101
# @>       stiffness-reduced: 0.115
# @>                  BLOSUM: 0.056
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 0-ANM-reduced-v2_EVmut
# @> 11472 out of 28010 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.846   OOB score = 0.842
# @> CV iteration # 2:    ROC-AUC = 0.834   OOB score = 0.843
# @> CV iteration # 3:    ROC-AUC = 0.841   OOB score = 0.842
# @> CV iteration # 4:    ROC-AUC = 0.856   OOB score = 0.842
# @> CV iteration # 5:    ROC-AUC = 0.849   OOB score = 0.844
# @> CV iteration # 6:    ROC-AUC = 0.840   OOB score = 0.841
# @> CV iteration # 7:    ROC-AUC = 0.835   OOB score = 0.841
# @> CV iteration # 8:    ROC-AUC = 0.838   OOB score = 0.842
# @> CV iteration # 9:    ROC-AUC = 0.850   OOB score = 0.841
# @> CV iteration #10:    ROC-AUC = 0.865   OOB score = 0.841
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   16538
# @> fraction of positives:   0.780
# @> mean ROC-AUC:            0.845
# @> mean OOB score:          0.842
# @> optimal cutoff*:         0.782 +/- 0.027
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.119
# @>              Delta_PSIC: 0.147
# @>                    SASA: 0.069
# @>         ANM_MSF-reduced: 0.068
# @> ANM_effectiveness-reduced: 0.071
# @> ANM_sensitivity-reduced: 0.067
# @>       stiffness-reduced: 0.073
# @>                 entropy: 0.093
# @>               ranked_MI: 0.071
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.180
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.842
# @> feature importances:
# @>                 wt_PSIC: 0.119
# @>              Delta_PSIC: 0.147
# @>                    SASA: 0.069
# @>         ANM_MSF-reduced: 0.068
# @> ANM_effectiveness-reduced: 0.071
# @> ANM_sensitivity-reduced: 0.067
# @>       stiffness-reduced: 0.073
# @>                 entropy: 0.092
# @>               ranked_MI: 0.071
# @>                  BLOSUM: 0.042
# @>      EVmut-DeltaE_epist: 0.179
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-GNM-chain-v2
# @> 5048 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.829   OOB score = 0.821
# @> CV iteration # 2:    ROC-AUC = 0.824   OOB score = 0.820
# @> CV iteration # 3:    ROC-AUC = 0.854   OOB score = 0.820
# @> CV iteration # 4:    ROC-AUC = 0.855   OOB score = 0.819
# @> CV iteration # 5:    ROC-AUC = 0.844   OOB score = 0.820
# @> CV iteration # 6:    ROC-AUC = 0.850   OOB score = 0.820
# @> CV iteration # 7:    ROC-AUC = 0.854   OOB score = 0.818
# @> CV iteration # 8:    ROC-AUC = 0.843   OOB score = 0.821
# @> CV iteration # 9:    ROC-AUC = 0.841   OOB score = 0.822
# @> CV iteration #10:    ROC-AUC = 0.874   OOB score = 0.819
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20524
# @> fraction of positives:   0.730
# @> mean ROC-AUC:            0.846
# @> mean OOB score:          0.820
# @> optimal cutoff*:         0.720 +/- 0.039
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.149
# @>              Delta_PSIC: 0.200
# @>                    SASA: 0.076
# @>           GNM_MSF-chain: 0.087
# @> GNM_effectiveness-chain: 0.082
# @>   GNM_sensitivity-chain: 0.082
# @>         stiffness-chain: 0.084
# @>                 entropy: 0.110
# @>               ranked_MI: 0.080
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.821
# @> feature importances:
# @>                 wt_PSIC: 0.150
# @>              Delta_PSIC: 0.199
# @>                    SASA: 0.076
# @>           GNM_MSF-chain: 0.088
# @> GNM_effectiveness-chain: 0.082
# @>   GNM_sensitivity-chain: 0.082
# @>         stiffness-chain: 0.084
# @>                 entropy: 0.109
# @>               ranked_MI: 0.080
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-GNM-chain-v2_noPfam
# @> 210 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.840   OOB score = 0.804
# @> CV iteration # 2:    ROC-AUC = 0.832   OOB score = 0.806
# @> CV iteration # 3:    ROC-AUC = 0.821   OOB score = 0.807
# @> CV iteration # 4:    ROC-AUC = 0.849   OOB score = 0.805
# @> CV iteration # 5:    ROC-AUC = 0.830   OOB score = 0.807
# @> CV iteration # 6:    ROC-AUC = 0.813   OOB score = 0.808
# @> CV iteration # 7:    ROC-AUC = 0.836   OOB score = 0.806
# @> CV iteration # 8:    ROC-AUC = 0.847   OOB score = 0.805
# @> CV iteration # 9:    ROC-AUC = 0.838   OOB score = 0.807
# @> CV iteration #10:    ROC-AUC = 0.831   OOB score = 0.806
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   25362
# @> fraction of positives:   0.709
# @> mean ROC-AUC:            0.833
# @> mean OOB score:          0.806
# @> optimal cutoff*:         0.715 +/- 0.032
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.186
# @>              Delta_PSIC: 0.232
# @>                    SASA: 0.098
# @>           GNM_MSF-chain: 0.111
# @> GNM_effectiveness-chain: 0.105
# @>   GNM_sensitivity-chain: 0.105
# @>         stiffness-chain: 0.106
# @>                  BLOSUM: 0.056
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.806
# @> feature importances:
# @>                 wt_PSIC: 0.186
# @>              Delta_PSIC: 0.233
# @>                    SASA: 0.098
# @>           GNM_MSF-chain: 0.111
# @> GNM_effectiveness-chain: 0.105
# @>   GNM_sensitivity-chain: 0.105
# @>         stiffness-chain: 0.106
# @>                  BLOSUM: 0.055
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-GNM-chain-v2_EVmut
# @> 10039 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.826   OOB score = 0.846
# @> CV iteration # 2:    ROC-AUC = 0.860   OOB score = 0.845
# @> CV iteration # 3:    ROC-AUC = 0.851   OOB score = 0.844
# @> CV iteration # 4:    ROC-AUC = 0.855   OOB score = 0.844
# @> CV iteration # 5:    ROC-AUC = 0.847   OOB score = 0.845
# @> CV iteration # 6:    ROC-AUC = 0.848   OOB score = 0.846
# @> CV iteration # 7:    ROC-AUC = 0.862   OOB score = 0.843
# @> CV iteration # 8:    ROC-AUC = 0.864   OOB score = 0.845
# @> CV iteration # 9:    ROC-AUC = 0.838   OOB score = 0.845
# @> CV iteration #10:    ROC-AUC = 0.852   OOB score = 0.845
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   15533
# @> fraction of positives:   0.781
# @> mean ROC-AUC:            0.850
# @> mean OOB score:          0.845
# @> optimal cutoff*:         0.791 +/- 0.017
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.117
# @>              Delta_PSIC: 0.147
# @>                    SASA: 0.067
# @>           GNM_MSF-chain: 0.075
# @> GNM_effectiveness-chain: 0.074
# @>   GNM_sensitivity-chain: 0.073
# @>         stiffness-chain: 0.071
# @>                 entropy: 0.089
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.175
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.845
# @> feature importances:
# @>                 wt_PSIC: 0.118
# @>              Delta_PSIC: 0.146
# @>                    SASA: 0.067
# @>           GNM_MSF-chain: 0.075
# @> GNM_effectiveness-chain: 0.074
# @>   GNM_sensitivity-chain: 0.074
# @>         stiffness-chain: 0.071
# @>                 entropy: 0.089
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.041
# @>      EVmut-DeltaE_epist: 0.176
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-v1
# @> 208 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.835   OOB score = 0.802
# @> CV iteration # 2:    ROC-AUC = 0.833   OOB score = 0.803
# @> CV iteration # 3:    ROC-AUC = 0.836   OOB score = 0.803
# @> CV iteration # 4:    ROC-AUC = 0.857   OOB score = 0.800
# @> CV iteration # 5:    ROC-AUC = 0.832   OOB score = 0.804
# @> CV iteration # 6:    ROC-AUC = 0.827   OOB score = 0.804
# @> CV iteration # 7:    ROC-AUC = 0.831   OOB score = 0.804
# @> CV iteration # 8:    ROC-AUC = 0.839   OOB score = 0.801
# @> CV iteration # 9:    ROC-AUC = 0.839   OOB score = 0.803
# @> CV iteration #10:    ROC-AUC = 0.833   OOB score = 0.804
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   25364
# @> fraction of positives:   0.709
# @> mean ROC-AUC:            0.836
# @> mean OOB score:          0.803
# @> optimal cutoff*:         0.727 +/- 0.020
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.191
# @>              Delta_PSIC: 0.254
# @>                    SASA: 0.100
# @>           GNM_MSF-chain: 0.118
# @> ANM_effectiveness-chain: 0.115
# @>   ANM_sensitivity-chain: 0.108
# @>         stiffness-chain: 0.113
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.804
# @> feature importances:
# @>                 wt_PSIC: 0.188
# @>              Delta_PSIC: 0.258
# @>                    SASA: 0.100
# @>           GNM_MSF-chain: 0.117
# @> ANM_effectiveness-chain: 0.116
# @>   ANM_sensitivity-chain: 0.108
# @>         stiffness-chain: 0.113
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-GNM-reduced-v2
# @> 5071 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.841   OOB score = 0.815
# @> CV iteration # 2:    ROC-AUC = 0.839   OOB score = 0.816
# @> CV iteration # 3:    ROC-AUC = 0.864   OOB score = 0.816
# @> CV iteration # 4:    ROC-AUC = 0.838   OOB score = 0.818
# @> CV iteration # 5:    ROC-AUC = 0.825   OOB score = 0.817
# @> CV iteration # 6:    ROC-AUC = 0.826   OOB score = 0.818
# @> CV iteration # 7:    ROC-AUC = 0.830   OOB score = 0.816
# @> CV iteration # 8:    ROC-AUC = 0.855   OOB score = 0.817
# @> CV iteration # 9:    ROC-AUC = 0.857   OOB score = 0.816
# @> CV iteration #10:    ROC-AUC = 0.839   OOB score = 0.817
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20501
# @> fraction of positives:   0.730
# @> mean ROC-AUC:            0.841
# @> mean OOB score:          0.817
# @> optimal cutoff*:         0.722 +/- 0.030
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.151
# @>              Delta_PSIC: 0.202
# @>                    SASA: 0.079
# @>         GNM_MSF-reduced: 0.084
# @> GNM_effectiveness-reduced: 0.077
# @> GNM_sensitivity-reduced: 0.078
# @>       stiffness-reduced: 0.084
# @>                 entropy: 0.112
# @>               ranked_MI: 0.081
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.816
# @> feature importances:
# @>                 wt_PSIC: 0.150
# @>              Delta_PSIC: 0.206
# @>                    SASA: 0.079
# @>         GNM_MSF-reduced: 0.084
# @> GNM_effectiveness-reduced: 0.077
# @> GNM_sensitivity-reduced: 0.079
# @>       stiffness-reduced: 0.084
# @>                 entropy: 0.112
# @>               ranked_MI: 0.081
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-GNM-reduced-v2_noPfam
# @> 243 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.832   OOB score = 0.801
# @> CV iteration # 2:    ROC-AUC = 0.828   OOB score = 0.804
# @> CV iteration # 3:    ROC-AUC = 0.826   OOB score = 0.803
# @> CV iteration # 4:    ROC-AUC = 0.828   OOB score = 0.802
# @> CV iteration # 5:    ROC-AUC = 0.844   OOB score = 0.801
# @> CV iteration # 6:    ROC-AUC = 0.810   OOB score = 0.802
# @> CV iteration # 7:    ROC-AUC = 0.815   OOB score = 0.802
# @> CV iteration # 8:    ROC-AUC = 0.812   OOB score = 0.803
# @> CV iteration # 9:    ROC-AUC = 0.835   OOB score = 0.802
# @> CV iteration #10:    ROC-AUC = 0.832   OOB score = 0.803
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   25329
# @> fraction of positives:   0.710
# @> mean ROC-AUC:            0.826
# @> mean OOB score:          0.802
# @> optimal cutoff*:         0.706 +/- 0.033
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.189
# @>              Delta_PSIC: 0.235
# @>                    SASA: 0.101
# @>         GNM_MSF-reduced: 0.110
# @> GNM_effectiveness-reduced: 0.101
# @> GNM_sensitivity-reduced: 0.102
# @>       stiffness-reduced: 0.106
# @>                  BLOSUM: 0.056
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.803
# @> feature importances:
# @>                 wt_PSIC: 0.189
# @>              Delta_PSIC: 0.236
# @>                    SASA: 0.101
# @>         GNM_MSF-reduced: 0.110
# @> GNM_effectiveness-reduced: 0.101
# @> GNM_sensitivity-reduced: 0.102
# @>       stiffness-reduced: 0.106
# @>                  BLOSUM: 0.056
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-GNM-reduced-v2_EVmut
# @> 10039 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.851   OOB score = 0.844
# @> CV iteration # 2:    ROC-AUC = 0.840   OOB score = 0.843
# @> CV iteration # 3:    ROC-AUC = 0.858   OOB score = 0.844
# @> CV iteration # 4:    ROC-AUC = 0.854   OOB score = 0.843
# @> CV iteration # 5:    ROC-AUC = 0.850   OOB score = 0.843
# @> CV iteration # 6:    ROC-AUC = 0.850   OOB score = 0.844
# @> CV iteration # 7:    ROC-AUC = 0.854   OOB score = 0.842
# @> CV iteration # 8:    ROC-AUC = 0.829   OOB score = 0.843
# @> CV iteration # 9:    ROC-AUC = 0.828   OOB score = 0.845
# @> CV iteration #10:    ROC-AUC = 0.834   OOB score = 0.842
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   15533
# @> fraction of positives:   0.781
# @> mean ROC-AUC:            0.845
# @> mean OOB score:          0.843
# @> optimal cutoff*:         0.762 +/- 0.032
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.119
# @>              Delta_PSIC: 0.148
# @>                    SASA: 0.068
# @>         GNM_MSF-reduced: 0.074
# @> GNM_effectiveness-reduced: 0.068
# @> GNM_sensitivity-reduced: 0.068
# @>       stiffness-reduced: 0.073
# @>                 entropy: 0.091
# @>               ranked_MI: 0.071
# @>                  BLOSUM: 0.042
# @>      EVmut-DeltaE_epist: 0.177
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.844
# @> feature importances:
# @>                 wt_PSIC: 0.119
# @>              Delta_PSIC: 0.148
# @>                    SASA: 0.068
# @>         GNM_MSF-reduced: 0.074
# @> GNM_effectiveness-reduced: 0.068
# @> GNM_sensitivity-reduced: 0.068
# @>       stiffness-reduced: 0.072
# @>                 entropy: 0.091
# @>               ranked_MI: 0.071
# @>                  BLOSUM: 0.042
# @>      EVmut-DeltaE_epist: 0.178
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-ANM-chain-v2
# @> 5046 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.833   OOB score = 0.822
# @> CV iteration # 2:    ROC-AUC = 0.850   OOB score = 0.819
# @> CV iteration # 3:    ROC-AUC = 0.859   OOB score = 0.819
# @> CV iteration # 4:    ROC-AUC = 0.847   OOB score = 0.819
# @> CV iteration # 5:    ROC-AUC = 0.833   OOB score = 0.820
# @> CV iteration # 6:    ROC-AUC = 0.842   OOB score = 0.821
# @> CV iteration # 7:    ROC-AUC = 0.858   OOB score = 0.817
# @> CV iteration # 8:    ROC-AUC = 0.848   OOB score = 0.819
# @> CV iteration # 9:    ROC-AUC = 0.850   OOB score = 0.820
# @> CV iteration #10:    ROC-AUC = 0.854   OOB score = 0.821
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   20526
# @> fraction of positives:   0.730
# @> mean ROC-AUC:            0.847
# @> mean OOB score:          0.820
# @> optimal cutoff*:         0.745 +/- 0.027
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.150
# @>              Delta_PSIC: 0.198
# @>                    SASA: 0.078
# @>           ANM_MSF-chain: 0.083
# @> ANM_effectiveness-chain: 0.086
# @>   ANM_sensitivity-chain: 0.079
# @>         stiffness-chain: 0.088
# @>                 entropy: 0.110
# @>               ranked_MI: 0.079
# @>                  BLOSUM: 0.050
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.821
# @> feature importances:
# @>                 wt_PSIC: 0.150
# @>              Delta_PSIC: 0.197
# @>                    SASA: 0.078
# @>           ANM_MSF-chain: 0.083
# @> ANM_effectiveness-chain: 0.086
# @>   ANM_sensitivity-chain: 0.079
# @>         stiffness-chain: 0.088
# @>                 entropy: 0.110
# @>               ranked_MI: 0.079
# @>                  BLOSUM: 0.049
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-ANM-chain-v2_noPfam
# @> 208 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.830   OOB score = 0.805
# @> CV iteration # 2:    ROC-AUC = 0.834   OOB score = 0.806
# @> CV iteration # 3:    ROC-AUC = 0.829   OOB score = 0.805
# @> CV iteration # 4:    ROC-AUC = 0.855   OOB score = 0.802
# @> CV iteration # 5:    ROC-AUC = 0.831   OOB score = 0.805
# @> CV iteration # 6:    ROC-AUC = 0.830   OOB score = 0.806
# @> CV iteration # 7:    ROC-AUC = 0.827   OOB score = 0.805
# @> CV iteration # 8:    ROC-AUC = 0.834   OOB score = 0.804
# @> CV iteration # 9:    ROC-AUC = 0.834   OOB score = 0.804
# @> CV iteration #10:    ROC-AUC = 0.841   OOB score = 0.805
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   25364
# @> fraction of positives:   0.709
# @> mean ROC-AUC:            0.834
# @> mean OOB score:          0.805
# @> optimal cutoff*:         0.728 +/- 0.033
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.187
# @>              Delta_PSIC: 0.231
# @>                    SASA: 0.100
# @>           ANM_MSF-chain: 0.105
# @> ANM_effectiveness-chain: 0.109
# @>   ANM_sensitivity-chain: 0.102
# @>         stiffness-chain: 0.110
# @>                  BLOSUM: 0.056
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.806
# @> feature importances:
# @>                 wt_PSIC: 0.188
# @>              Delta_PSIC: 0.231
# @>                    SASA: 0.100
# @>           ANM_MSF-chain: 0.105
# @> ANM_effectiveness-chain: 0.109
# @>   ANM_sensitivity-chain: 0.102
# @>         stiffness-chain: 0.110
# @>                  BLOSUM: 0.055
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 100-ANM-chain-v2_EVmut
# @> 10037 out of 25572 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.834   OOB score = 0.848
# @> CV iteration # 2:    ROC-AUC = 0.862   OOB score = 0.845
# @> CV iteration # 3:    ROC-AUC = 0.843   OOB score = 0.847
# @> CV iteration # 4:    ROC-AUC = 0.847   OOB score = 0.845
# ...
# @> Classifier training summary:
# @> mean OOB score:          0.823
# @> feature importances:
# @>                 wt_PSIC: 0.212
# @>              Delta_PSIC: 0.225
# @>                    SASA: 0.098
# @>         GNM_MSF-reduced: 0.104
# @> GNM_effectiveness-reduced: 0.101
# @> GNM_sensitivity-reduced: 0.097
# @>       stiffness-reduced: 0.104
# @>                  BLOSUM: 0.058
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 600-GNM-reduced-v2_EVmut
# @> 2129 out of 4645 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.807   OOB score = 0.871
# @> CV iteration # 2:    ROC-AUC = 0.910   OOB score = 0.865
# @> CV iteration # 3:    ROC-AUC = 0.859   OOB score = 0.867
# @> CV iteration # 4:    ROC-AUC = 0.794   OOB score = 0.871
# @> CV iteration # 5:    ROC-AUC = 0.879   OOB score = 0.867
# @> CV iteration # 6:    ROC-AUC = 0.845   OOB score = 0.871
# @> CV iteration # 7:    ROC-AUC = 0.821   OOB score = 0.868
# @> CV iteration # 8:    ROC-AUC = 0.895   OOB score = 0.868
# @> CV iteration # 9:    ROC-AUC = 0.868   OOB score = 0.871
# @> CV iteration #10:    ROC-AUC = 0.857   OOB score = 0.868
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   2516
# @> fraction of positives:   0.820
# @> mean ROC-AUC:            0.853
# @> mean OOB score:          0.869
# @> optimal cutoff*:         0.774 +/- 0.083
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.154
# @>              Delta_PSIC: 0.152
# @>                    SASA: 0.063
# @>         GNM_MSF-reduced: 0.065
# @> GNM_effectiveness-reduced: 0.075
# @> GNM_sensitivity-reduced: 0.066
# @>       stiffness-reduced: 0.064
# @>                 entropy: 0.084
# @>               ranked_MI: 0.072
# @>                  BLOSUM: 0.045
# @>      EVmut-DeltaE_epist: 0.159
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.867
# @> feature importances:
# @>                 wt_PSIC: 0.151
# @>              Delta_PSIC: 0.157
# @>                    SASA: 0.064
# @>         GNM_MSF-reduced: 0.065
# @> GNM_effectiveness-reduced: 0.076
# @> GNM_sensitivity-reduced: 0.066
# @>       stiffness-reduced: 0.064
# @>                 entropy: 0.082
# @>               ranked_MI: 0.072
# @>                  BLOSUM: 0.045
# @>      EVmut-DeltaE_epist: 0.158
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 600-ANM-chain-v2
# @> 1507 out of 4645 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.846   OOB score = 0.846
# @> CV iteration # 2:    ROC-AUC = 0.897   OOB score = 0.843
# @> CV iteration # 3:    ROC-AUC = 0.845   OOB score = 0.843
# @> CV iteration # 4:    ROC-AUC = 0.836   OOB score = 0.846
# @> CV iteration # 5:    ROC-AUC = 0.895   OOB score = 0.843
# @> CV iteration # 6:    ROC-AUC = 0.841   OOB score = 0.842
# @> CV iteration # 7:    ROC-AUC = 0.872   OOB score = 0.843
# @> CV iteration # 8:    ROC-AUC = 0.839   OOB score = 0.844
# @> CV iteration # 9:    ROC-AUC = 0.778   OOB score = 0.844
# @> CV iteration #10:    ROC-AUC = 0.885   OOB score = 0.841
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   3138
# @> fraction of positives:   0.779
# @> mean ROC-AUC:            0.853
# @> mean OOB score:          0.843
# @> optimal cutoff*:         0.757 +/- 0.062
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.189
# @>              Delta_PSIC: 0.183
# @>                    SASA: 0.077
# @>           ANM_MSF-chain: 0.080
# @> ANM_effectiveness-chain: 0.084
# @>   ANM_sensitivity-chain: 0.078
# @>         stiffness-chain: 0.078
# @>                 entropy: 0.098
# @>               ranked_MI: 0.083
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.847
# @> feature importances:
# @>                 wt_PSIC: 0.185
# @>              Delta_PSIC: 0.188
# @>                    SASA: 0.077
# @>           ANM_MSF-chain: 0.080
# @> ANM_effectiveness-chain: 0.084
# @>   ANM_sensitivity-chain: 0.078
# @>         stiffness-chain: 0.078
# @>                 entropy: 0.097
# @>               ranked_MI: 0.083
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 600-ANM-chain-v2_noPfam
# @> 139 out of 4645 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.838   OOB score = 0.820
# @> CV iteration # 2:    ROC-AUC = 0.873   OOB score = 0.820
# @> CV iteration # 3:    ROC-AUC = 0.807   OOB score = 0.826
# @> CV iteration # 4:    ROC-AUC = 0.810   OOB score = 0.825
# @> CV iteration # 5:    ROC-AUC = 0.835   OOB score = 0.824
# @> CV iteration # 6:    ROC-AUC = 0.817   OOB score = 0.826
# @> CV iteration # 7:    ROC-AUC = 0.852   OOB score = 0.823
# @> CV iteration # 8:    ROC-AUC = 0.822   OOB score = 0.830
# @> CV iteration # 9:    ROC-AUC = 0.862   OOB score = 0.824
# @> CV iteration #10:    ROC-AUC = 0.814   OOB score = 0.823
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   4506
# @> fraction of positives:   0.761
# @> mean ROC-AUC:            0.833
# @> mean OOB score:          0.824
# @> optimal cutoff*:         0.754 +/- 0.050
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.215
# @>              Delta_PSIC: 0.219
# @>                    SASA: 0.098
# @>           ANM_MSF-chain: 0.103
# @> ANM_effectiveness-chain: 0.104
# @>   ANM_sensitivity-chain: 0.100
# @>         stiffness-chain: 0.101
# @>                  BLOSUM: 0.059
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.827
# @> feature importances:
# @>                 wt_PSIC: 0.217
# @>              Delta_PSIC: 0.218
# @>                    SASA: 0.099
# @>           ANM_MSF-chain: 0.103
# @> ANM_effectiveness-chain: 0.104
# @>   ANM_sensitivity-chain: 0.100
# @>         stiffness-chain: 0.101
# @>                  BLOSUM: 0.059
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 600-ANM-chain-v2_EVmut
# @> 2129 out of 4645 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.828   OOB score = 0.875
# @> CV iteration # 2:    ROC-AUC = 0.926   OOB score = 0.865
# @> CV iteration # 3:    ROC-AUC = 0.868   OOB score = 0.867
# @> CV iteration # 4:    ROC-AUC = 0.831   OOB score = 0.871
# @> CV iteration # 5:    ROC-AUC = 0.877   OOB score = 0.867
# @> CV iteration # 6:    ROC-AUC = 0.823   OOB score = 0.872
# @> CV iteration # 7:    ROC-AUC = 0.835   OOB score = 0.871
# @> CV iteration # 8:    ROC-AUC = 0.897   OOB score = 0.872
# @> CV iteration # 9:    ROC-AUC = 0.878   OOB score = 0.870
# @> CV iteration #10:    ROC-AUC = 0.870   OOB score = 0.865
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   2516
# @> fraction of positives:   0.820
# @> mean ROC-AUC:            0.862
# @> mean OOB score:          0.869
# @> optimal cutoff*:         0.802 +/- 0.064
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.152
# @>              Delta_PSIC: 0.152
# @>                    SASA: 0.062
# @>           ANM_MSF-chain: 0.066
# @> ANM_effectiveness-chain: 0.079
# @>   ANM_sensitivity-chain: 0.072
# @>         stiffness-chain: 0.064
# @>                 entropy: 0.082
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.045
# @>      EVmut-DeltaE_epist: 0.159
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.870
# @> feature importances:
# @>                 wt_PSIC: 0.153
# @>              Delta_PSIC: 0.153
# @>                    SASA: 0.060
# @>           ANM_MSF-chain: 0.066
# @> ANM_effectiveness-chain: 0.079
# @>   ANM_sensitivity-chain: 0.071
# @>         stiffness-chain: 0.064
# @>                 entropy: 0.082
# @>               ranked_MI: 0.069
# @>                  BLOSUM: 0.045
# @>      EVmut-DeltaE_epist: 0.157
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 600-ANM-reduced-v2
# @> 1513 out of 4645 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.866   OOB score = 0.850
# @> CV iteration # 2:    ROC-AUC = 0.850   OOB score = 0.851
# @> CV iteration # 3:    ROC-AUC = 0.858   OOB score = 0.850
# @> CV iteration # 4:    ROC-AUC = 0.847   OOB score = 0.851
# @> CV iteration # 5:    ROC-AUC = 0.875   OOB score = 0.847
# @> CV iteration # 6:    ROC-AUC = 0.869   OOB score = 0.847
# @> CV iteration # 7:    ROC-AUC = 0.873   OOB score = 0.852
# @> CV iteration # 8:    ROC-AUC = 0.824   OOB score = 0.851
# @> CV iteration # 9:    ROC-AUC = 0.832   OOB score = 0.850
# @> CV iteration #10:    ROC-AUC = 0.845   OOB score = 0.849
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   3132
# @> fraction of positives:   0.780
# @> mean ROC-AUC:            0.853
# @> mean OOB score:          0.850
# @> optimal cutoff*:         0.773 +/- 0.037
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.184
# @>              Delta_PSIC: 0.184
# @>                    SASA: 0.076
# @>         ANM_MSF-reduced: 0.076
# @> ANM_effectiveness-reduced: 0.098
# @> ANM_sensitivity-reduced: 0.079
# @>       stiffness-reduced: 0.078
# @>                 entropy: 0.095
# @>               ranked_MI: 0.080
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.850
# @> feature importances:
# @>                 wt_PSIC: 0.183
# @>              Delta_PSIC: 0.183
# @>                    SASA: 0.076
# @>         ANM_MSF-reduced: 0.076
# @> ANM_effectiveness-reduced: 0.098
# @> ANM_sensitivity-reduced: 0.078
# @>       stiffness-reduced: 0.079
# @>                 entropy: 0.095
# @>               ranked_MI: 0.081
# @>                  BLOSUM: 0.051
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 600-ANM-reduced-v2_noPfam
# @> 146 out of 4645 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.867   OOB score = 0.831
# @> CV iteration # 2:    ROC-AUC = 0.849   OOB score = 0.833
# @> CV iteration # 3:    ROC-AUC = 0.838   OOB score = 0.830
# @> CV iteration # 4:    ROC-AUC = 0.831   OOB score = 0.831
# @> CV iteration # 5:    ROC-AUC = 0.841   OOB score = 0.829
# @> CV iteration # 6:    ROC-AUC = 0.846   OOB score = 0.832
# @> CV iteration # 7:    ROC-AUC = 0.864   OOB score = 0.833
# @> CV iteration # 8:    ROC-AUC = 0.824   OOB score = 0.835
# @> CV iteration # 9:    ROC-AUC = 0.840   OOB score = 0.830
# @> CV iteration #10:    ROC-AUC = 0.853   OOB score = 0.831
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   4499
# @> fraction of positives:   0.761
# @> mean ROC-AUC:            0.845
# @> mean OOB score:          0.831
# @> optimal cutoff*:         0.724 +/- 0.045
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.209
# @>              Delta_PSIC: 0.217
# @>                    SASA: 0.098
# @>         ANM_MSF-reduced: 0.100
# @> ANM_effectiveness-reduced: 0.112
# @> ANM_sensitivity-reduced: 0.101
# @>       stiffness-reduced: 0.103
# @>                  BLOSUM: 0.059
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.835
# @> feature importances:
# @>                 wt_PSIC: 0.210
# @>              Delta_PSIC: 0.217
# @>                    SASA: 0.098
# @>         ANM_MSF-reduced: 0.100
# @> ANM_effectiveness-reduced: 0.112
# @> ANM_sensitivity-reduced: 0.102
# @>       stiffness-reduced: 0.103
# @>                  BLOSUM: 0.058
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> CLASSIFICATION SCHEME: 600-ANM-reduced-v2_EVmut
# @> 2129 out of 4645 cases ignored with missing features.
# @> CV iteration # 1:    ROC-AUC = 0.838   OOB score = 0.874
# @> CV iteration # 2:    ROC-AUC = 0.928   OOB score = 0.876
# @> CV iteration # 3:    ROC-AUC = 0.853   OOB score = 0.875
# @> CV iteration # 4:    ROC-AUC = 0.808   OOB score = 0.878
# @> CV iteration # 5:    ROC-AUC = 0.876   OOB score = 0.872
# @> CV iteration # 6:    ROC-AUC = 0.857   OOB score = 0.873
# @> CV iteration # 7:    ROC-AUC = 0.839   OOB score = 0.875
# @> CV iteration # 8:    ROC-AUC = 0.899   OOB score = 0.877
# @> CV iteration # 9:    ROC-AUC = 0.874   OOB score = 0.877
# @> CV iteration #10:    ROC-AUC = 0.882   OOB score = 0.874
# @> ------------------------------------------------------------
# @> Cross-validation summary:
# @> training dataset size:   2516
# @> fraction of positives:   0.820
# @> mean ROC-AUC:            0.865
# @> mean OOB score:          0.875
# @> optimal cutoff*:         0.794 +/- 0.071
# @> (* argmax of Youden's index)
# @> feature importances:
# @>                 wt_PSIC: 0.148
# @>              Delta_PSIC: 0.153
# @>                    SASA: 0.062
# @>         ANM_MSF-reduced: 0.062
# @> ANM_effectiveness-reduced: 0.090
# @> ANM_sensitivity-reduced: 0.071
# @>       stiffness-reduced: 0.062
# @>                 entropy: 0.080
# @>               ranked_MI: 0.067
# @>                  BLOSUM: 0.045
# @>      EVmut-DeltaE_epist: 0.158
# @> ------------------------------------------------------------
# @> Predictions distribution saved to predictions_distribution.png
# @> Pathogenicity plot saved to pathogenicity_prob.png
# @> ROC plot saved to ROC.png
# @> ------------------------------------------------------------
# @> Classifier training summary:
# @> mean OOB score:          0.875
# @> feature importances:
# @>                 wt_PSIC: 0.149
# @>              Delta_PSIC: 0.152
# @>                    SASA: 0.063
# @>         ANM_MSF-reduced: 0.061
# @> ANM_effectiveness-reduced: 0.089
# @> ANM_sensitivity-reduced: 0.072
# @>       stiffness-reduced: 0.062
# @>                 entropy: 0.083
# @>               ranked_MI: 0.067
# @>                  BLOSUM: 0.046
# @>      EVmut-DeltaE_epist: 0.157
# @> ------------------------------------------------------------
# @> Feat. importance plot saved to feat_importances.png
# @>
# @> Logging stopped at 2019-02-06 22:45:09.430428
# @> Closing logfile: results/RF_training.log

# %%
# recover precomputed cross-validation results
CV_summaries = pickle.load(open('results/CV_summaries.pkl', 'rb'))

# %% [markdown]
# ## Figures

# %%
os.mkdir('figures')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 3, figsize=(12,7))
fig.subplots_adjust(wspace=0.2)

ax[0,0].set_title('RHAPSODY')
ax[0,1].set_title('RHAPSODY w/o Pfam features')
ax[0,2].set_title('RHAPSODY w/ EVmutation score')
ax[0,0].set_ylabel('AUROC')
ax[1,0].set_ylabel('OOB score')
for j in range(3):
    ax[0,j].set_ylim([.80, .88])
    ax[1,j].set_ylim([.80, .88])
    ax[1,j].set_xlabel('minimum number of residues')

x = [0, 100, 150, 200, 300, 400, 500, 600]
for ENM in ['GNM', 'ANM']:
    for model in ['chain', 'reduced']:
        for i, version in enumerate(['v2', 'v2_noPfam', 'v2_EVmut']):
            scheme = f'{ENM}-{model}-{version}'
            AUC = [CV_summaries[f'{n}-{scheme}']['mean ROC-AUC'] for n in x]
            OOB = [CV_summaries[f'{n}-{scheme}']['mean OOB score'] for n in x]
            ax[0,i].plot(x, AUC, 'o-', label=scheme)
            ax[1,i].plot(x, OOB, 'o-', label=scheme)

AUC = [CV_summaries[f'{n}-v1']['mean ROC-AUC'] for n in x]
OOB = [CV_summaries[f'{n}-v1']['mean OOB score'] for n in x]
ax[0,0].plot(x, AUC, 'v--', label='v1')
ax[1,0].plot(x, OOB, 'v--', label='v1')

ax[0,0].legend(fontsize=8)

plt.tight_layout()
fig.savefig('figures/performances_comparison.png', dpi=300)

# %%
fig, ax = plt.subplots(2, 3, figsize=(12,7))
fig.subplots_adjust(wspace=0.2)

featsets = {}
featsets['v2'] = ['wt_PSIC', 'Delta_PSIC', 'SASA', 'MSF', 
                  'effectiveness', 'sensitivity', 'stiffness', 
                  'entropy', 'ranked_MI', 'BLOSUM']
featsets['v2_noPfam'] = ['wt_PSIC', 'Delta_PSIC', 'SASA', 'MSF', 
                         'effectiveness', 'sensitivity', 'stiffness', 'BLOSUM']
featsets['v2_EVmut'] = featsets['v2'] + ['EVmut-DeltaE',]
SEQ_feats = ['wt_PSIC', 'Delta_PSIC', 'BLOSUM', 'entropy', 'ranked_MI', 'EVmut-DeltaE']

ax[0,0].set_title('RHAPSODY')
ax[0,1].set_title('RHAPSODY w/o Pfam features')
ax[0,2].set_title('RHAPSODY w/ EVmutation score')
ax[0,0].set_ylabel('sequence-based features')
ax[1,0].set_ylabel('structure-based features')
for j in range(3):
    ax[0,j].set_ylim([0, .3])
    ax[1,j].set_ylim([0, .13])
    ax[1,j].set_xlabel('minimum number of residues')

x = [0, 100, 150, 200, 300, 400, 500, 600]

for i, (version, featset) in enumerate(featsets.items()):
    for j,f in enumerate(featset):
        ss = [CV_summaries[f'{n}-ANM-chain-{version}']['feat. importance'][j] for n in x]
        if f in ['BLOSUM', 'SASA']:
            m = 'kv-'
        else:
            m = 'o-'
        if f in SEQ_feats:
            ax[0,i].plot(x, ss, m, label=f)
        else:
            ax[1,i].plot(x, ss, m, label=f)
            
for a in ax[0]:
    a.legend(loc='upper right', ncol=2)
for a in ax[1]:
    a.legend(loc='lower right', ncol=2)

plt.tight_layout()
fig.savefig('figures/feat_imp_comparison.png', dpi=300)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7.5,3))
fig.subplots_adjust(wspace=0.2)

x = [0, 100, 150, 200, 300, 400, 500, 600]

y = np.array([CV_summaries[f'{n}-ANM-chain-v2']['dataset size'] for n in x])
ax1.plot(x, y, 'o-')
ax1.set_xlabel('minimum number of residues')
ax1.set_ylabel('number of SAVs')

y2 = np.array([CV_summaries[f'{n}-ANM-chain-v2']['dataset bias'] for n in x])
ax2.plot(x, y2, 'o-')
ax2.set_xlabel('minimum number of residues')
ax2.set_ylabel('fraction of del. SAVs')
ax2.set_ylim((0.7, 0.8))

plt.tight_layout()
fig.savefig('figures/stats.png', dpi=300)

# %% [markdown]
# ## Summary

# %%
for version in ['v2', 'v2_noPfam', 'v2_EVmut', 'v1']:
    for min_num_res in [0, 100, 150, 200, 300, 400, 500, 600]:
        for ENM in ['GNM', 'ANM']:
            for model in ['chain', 'reduced']:

                if version == 'v1' and ENM == 'GNM' and model == 'chain':
                    scheme = f'{min_num_res}-v1'
                elif version != 'v1':
                    scheme = f'{min_num_res}-{ENM}-{model}-{version}'
                else:
                    continue

                s = CV_summaries[scheme]
               
                print(f'{version:<9} {min_num_res:3} {ENM} {model:7}:  ',
                      'size = {:5}  '.format(s['dataset size']),
                      'AUROC = {:5.3f}  '.format(s['mean ROC-AUC']),
                      'OOB = {:5.3f}'.format(s['mean OOB score']) )
# Out:
# v2          0 GNM chain  :   size = 22055   AUROC = 0.844   OOB = 0.818
# v2          0 GNM reduced:   size = 22032   AUROC = 0.840   OOB = 0.814
# v2          0 ANM chain  :   size = 22057   AUROC = 0.844   OOB = 0.818
# v2          0 ANM reduced:   size = 22032   AUROC = 0.843   OOB = 0.814
# v2        100 GNM chain  :   size = 20524   AUROC = 0.846   OOB = 0.820
# v2        100 GNM reduced:   size = 20501   AUROC = 0.841   OOB = 0.817
# v2        100 ANM chain  :   size = 20526   AUROC = 0.847   OOB = 0.820
# v2        100 ANM reduced:   size = 20501   AUROC = 0.844   OOB = 0.816
# v2        150 GNM chain  :   size = 18800   AUROC = 0.851   OOB = 0.824
# v2        150 GNM reduced:   size = 18775   AUROC = 0.844   OOB = 0.820
# v2        150 ANM chain  :   size = 18800   AUROC = 0.851   OOB = 0.823
# v2        150 ANM reduced:   size = 18775   AUROC = 0.847   OOB = 0.818
# v2        200 GNM chain  :   size = 16806   AUROC = 0.846   OOB = 0.827
# v2        200 GNM reduced:   size = 16784   AUROC = 0.840   OOB = 0.824
# v2        200 ANM chain  :   size = 16806   AUROC = 0.850   OOB = 0.827
# v2        200 ANM reduced:   size = 16784   AUROC = 0.843   OOB = 0.823
# v2        300 GNM chain  :   size = 11542   AUROC = 0.823   OOB = 0.824
# v2        300 GNM reduced:   size = 11530   AUROC = 0.818   OOB = 0.824
# v2        300 ANM chain  :   size = 11542   AUROC = 0.829   OOB = 0.827
# v2        300 ANM reduced:   size = 11530   AUROC = 0.828   OOB = 0.826
# v2        400 GNM chain  :   size =  7630   AUROC = 0.834   OOB = 0.830
# v2        400 GNM reduced:   size =  7621   AUROC = 0.825   OOB = 0.828
# v2        400 ANM chain  :   size =  7630   AUROC = 0.838   OOB = 0.832
# v2        400 ANM reduced:   size =  7621   AUROC = 0.838   OOB = 0.834
# v2        500 GNM chain  :   size =  4573   AUROC = 0.846   OOB = 0.841
# v2        500 GNM reduced:   size =  4567   AUROC = 0.838   OOB = 0.844
# v2        500 ANM chain  :   size =  4573   AUROC = 0.851   OOB = 0.844
# v2        500 ANM reduced:   size =  4567   AUROC = 0.846   OOB = 0.848
# v2        600 GNM chain  :   size =  3138   AUROC = 0.845   OOB = 0.841
# v2        600 GNM reduced:   size =  3132   AUROC = 0.838   OOB = 0.843
# v2        600 ANM chain  :   size =  3138   AUROC = 0.853   OOB = 0.843
# v2        600 ANM reduced:   size =  3132   AUROC = 0.853   OOB = 0.850
# v2_noPfam   0 GNM chain  :   size = 27695   AUROC = 0.832   OOB = 0.805
# v2_noPfam   0 GNM reduced:   size = 27662   AUROC = 0.825   OOB = 0.801
# v2_noPfam   0 ANM chain  :   size = 27697   AUROC = 0.832   OOB = 0.804
# v2_noPfam   0 ANM reduced:   size = 27662   AUROC = 0.829   OOB = 0.802
# v2_noPfam 100 GNM chain  :   size = 25362   AUROC = 0.833   OOB = 0.806
# v2_noPfam 100 GNM reduced:   size = 25329   AUROC = 0.826   OOB = 0.802
# v2_noPfam 100 ANM chain  :   size = 25364   AUROC = 0.834   OOB = 0.805
# v2_noPfam 100 ANM reduced:   size = 25329   AUROC = 0.831   OOB = 0.803
# v2_noPfam 150 GNM chain  :   size = 23180   AUROC = 0.835   OOB = 0.809
# v2_noPfam 150 GNM reduced:   size = 23145   AUROC = 0.830   OOB = 0.805
# v2_noPfam 150 ANM chain  :   size = 23180   AUROC = 0.837   OOB = 0.808
# v2_noPfam 150 ANM reduced:   size = 23145   AUROC = 0.833   OOB = 0.805
# v2_noPfam 200 GNM chain  :   size = 20649   AUROC = 0.833   OOB = 0.812
# v2_noPfam 200 GNM reduced:   size = 20617   AUROC = 0.825   OOB = 0.807
# v2_noPfam 200 ANM chain  :   size = 20649   AUROC = 0.837   OOB = 0.811
# v2_noPfam 200 ANM reduced:   size = 20617   AUROC = 0.830   OOB = 0.808
# v2_noPfam 300 GNM chain  :   size = 14659   AUROC = 0.812   OOB = 0.807
# v2_noPfam 300 GNM reduced:   size = 14638   AUROC = 0.811   OOB = 0.808
# v2_noPfam 300 ANM chain  :   size = 14659   AUROC = 0.817   OOB = 0.807
# v2_noPfam 300 ANM reduced:   size = 14638   AUROC = 0.819   OOB = 0.809
# v2_noPfam 400 GNM chain  :   size = 10006   AUROC = 0.819   OOB = 0.815
# v2_noPfam 400 GNM reduced:   size =  9991   AUROC = 0.813   OOB = 0.814
# v2_noPfam 400 ANM chain  :   size = 10006   AUROC = 0.825   OOB = 0.814
# v2_noPfam 400 ANM reduced:   size =  9991   AUROC = 0.827   OOB = 0.818
# v2_noPfam 500 GNM chain  :   size =  6300   AUROC = 0.828   OOB = 0.820
# v2_noPfam 500 GNM reduced:   size =  6293   AUROC = 0.824   OOB = 0.821
# v2_noPfam 500 ANM chain  :   size =  6300   AUROC = 0.831   OOB = 0.824
# v2_noPfam 500 ANM reduced:   size =  6293   AUROC = 0.837   OOB = 0.828
# v2_noPfam 600 GNM chain  :   size =  4506   AUROC = 0.828   OOB = 0.821
# v2_noPfam 600 GNM reduced:   size =  4499   AUROC = 0.825   OOB = 0.822
# v2_noPfam 600 ANM chain  :   size =  4506   AUROC = 0.833   OOB = 0.824
# v2_noPfam 600 ANM reduced:   size =  4499   AUROC = 0.845   OOB = 0.831
# v2_EVmut    0 GNM chain  :   size = 16538   AUROC = 0.852   OOB = 0.844
# v2_EVmut    0 GNM reduced:   size = 16538   AUROC = 0.846   OOB = 0.842
# v2_EVmut    0 ANM chain  :   size = 16540   AUROC = 0.852   OOB = 0.845
# v2_EVmut    0 ANM reduced:   size = 16538   AUROC = 0.845   OOB = 0.842
# v2_EVmut  100 GNM chain  :   size = 15533   AUROC = 0.850   OOB = 0.845
# v2_EVmut  100 GNM reduced:   size = 15533   AUROC = 0.845   OOB = 0.843
# v2_EVmut  100 ANM chain  :   size = 15535   AUROC = 0.852   OOB = 0.846
# v2_EVmut  100 ANM reduced:   size = 15533   AUROC = 0.846   OOB = 0.843
# v2_EVmut  150 GNM chain  :   size = 14473   AUROC = 0.853   OOB = 0.848
# v2_EVmut  150 GNM reduced:   size = 14471   AUROC = 0.847   OOB = 0.847
# v2_EVmut  150 ANM chain  :   size = 14473   AUROC = 0.855   OOB = 0.851
# v2_EVmut  150 ANM reduced:   size = 14471   AUROC = 0.848   OOB = 0.848
# v2_EVmut  200 GNM chain  :   size = 13114   AUROC = 0.848   OOB = 0.852
# v2_EVmut  200 GNM reduced:   size = 13112   AUROC = 0.841   OOB = 0.851
# v2_EVmut  200 ANM chain  :   size = 13114   AUROC = 0.854   OOB = 0.854
# v2_EVmut  200 ANM reduced:   size = 13112   AUROC = 0.842   OOB = 0.852
# v2_EVmut  300 GNM chain  :   size =  9110   AUROC = 0.834   OOB = 0.853
# v2_EVmut  300 GNM reduced:   size =  9108   AUROC = 0.829   OOB = 0.852
# v2_EVmut  300 ANM chain  :   size =  9110   AUROC = 0.842   OOB = 0.854
# v2_EVmut  300 ANM reduced:   size =  9108   AUROC = 0.833   OOB = 0.854
# v2_EVmut  400 GNM chain  :   size =  6052   AUROC = 0.840   OOB = 0.858
# v2_EVmut  400 GNM reduced:   size =  6052   AUROC = 0.835   OOB = 0.856
# v2_EVmut  400 ANM chain  :   size =  6052   AUROC = 0.851   OOB = 0.861
# v2_EVmut  400 ANM reduced:   size =  6052   AUROC = 0.848   OOB = 0.860
# v2_EVmut  500 GNM chain  :   size =  3577   AUROC = 0.846   OOB = 0.867
# v2_EVmut  500 GNM reduced:   size =  3577   AUROC = 0.845   OOB = 0.867
# v2_EVmut  500 ANM chain  :   size =  3577   AUROC = 0.852   OOB = 0.867
# v2_EVmut  500 ANM reduced:   size =  3577   AUROC = 0.849   OOB = 0.869
# v2_EVmut  600 GNM chain  :   size =  2516   AUROC = 0.860   OOB = 0.867
# v2_EVmut  600 GNM reduced:   size =  2516   AUROC = 0.853   OOB = 0.869
# v2_EVmut  600 ANM chain  :   size =  2516   AUROC = 0.862   OOB = 0.869
# v2_EVmut  600 ANM reduced:   size =  2516   AUROC = 0.865   OOB = 0.875
# v1          0 GNM chain  :   size = 27697   AUROC = 0.833   OOB = 0.802
# v1        100 GNM chain  :   size = 25364   AUROC = 0.836   OOB = 0.803
# v1        150 GNM chain  :   size = 23180   AUROC = 0.838   OOB = 0.806
# v1        200 GNM chain  :   size = 20649   AUROC = 0.836   OOB = 0.808
# v1        300 GNM chain  :   size = 14659   AUROC = 0.813   OOB = 0.805
# v1        400 GNM chain  :   size = 10006   AUROC = 0.819   OOB = 0.811
# v1        500 GNM chain  :   size =  6300   AUROC = 0.825   OOB = 0.817
# v1        600 GNM chain  :   size =  4506   AUROC = 0.828   OOB = 0.822
